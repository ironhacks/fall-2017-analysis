# %% [markdown]
# ## Descriptive Analysis UNAL 1 Fall 2017 ( No Transparency )

# %% [markdown]
# ## Construct panel data for UNAL 1 with colors

# %%
import pandas as pd
import seaborn as sns

df_45 = pd.read_csv("../data/Unal-1-Phase-4-_Unal-1-Phase-5–raw-results.csv")
df_34 = pd.read_csv("../data/Unal-1-Phase-3-_Unal-1-Phase-4–raw-results.csv")
df_23 = pd.read_csv("../data/Unal-1-Phase-2-_Unal-1-Phase-3–raw-results.csv")
df_12 = pd.read_csv("../data/Unal-1-Phase-1-_Unal-1-Phase-2–raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7533  www.ironhacks.com  www.ironhacks.com
# 7534  www.ironhacks.com  www.ironhacks.com
# 7535  www.ironhacks.com  www.ironhacks.com
# 7536  www.ironhacks.com  www.ironhacks.com
# 7537  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...
# 1     http://www.ironhacks.com/preview/Caadiazsi/web...
# 2     http://www.ironhacks.com/preview/Caadiazsi/web...
# 3     http://www.ironhacks.com/preview/Caadiazsi/web...
# 4     http://www.ironhacks.com/preview/Caadiazsi/web...
# ...                                                 ...
# 7533  http://www.ironhacks.com/preview/yaochoal/weba...
# 7534  http://www.ironhacks.com/preview/yaochoal/weba...
# 7535  http://www.ironhacks.com/preview/yaochoal/weba...
# 7536  http://www.ironhacks.com/preview/yaochoal/weba...
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...
#
#                                                   link2 comparison_type  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...            maps
# 1     http://www.ironhacks.com/preview/Joacampora/we...            maps
# 2     http://www.ironhacks.com/preview/Juankmilo97/w...            maps
# 3     http://www.ironhacks.com/preview/Jufcardenasmo...            maps
# 4     http://www.ironhacks.com/preview/casc3798/weba...            maps
# ...                                                 ...             ...
# 7533  http://www.ironhacks.com/preview/olimita/webap...          simple
# 7534  http://www.ironhacks.com/preview/sebcamacho170...          simple
# 7535  http://www.ironhacks.com/preview/serbatero/web...          simple
# 7536  http://www.ironhacks.com/preview/xFortich/weba...          simple
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...          simple
#
#        ssim  features2d  stage
# 0     100.0       100.0      1
# 1      21.5        40.2      1
# 2      16.9        36.1      1
# 3      35.6        39.2      1
# 4      12.7        33.3      1
# ...     ...         ...    ...
# 7533   24.7        77.4      4
# 7534   73.9        61.9      4
# 7535   34.8        79.0      4
# 7536   78.7        84.3      4
# 7537   99.6       100.0      4
#
# [7538 rows x 8 columns]

# %%
ax = sns.lineplot(data=df_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Construct panel data for UNAL 1 with no colors

# %%
df_45 = pd.read_csv("../data/Unal-1-Phase-4-_Unal-1-Phase-5–no-color-raw-results.csv")
df_34 = pd.read_csv("../data/Unal-1-Phase-3-_Unal-1-Phase-4–no-color-raw-results.csv")
df_23 = pd.read_csv("../data/Unal-1-Phase-2-_Unal-1-Phase-3–no-color-raw-results.csv")
df_12 = pd.read_csv("../data/Unal-1-Phase-1-_Unal-1-Phase-2–no-color-raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_no_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7533  www.ironhacks.com  www.ironhacks.com
# 7534  www.ironhacks.com  www.ironhacks.com
# 7535  www.ironhacks.com  www.ironhacks.com
# 7536  www.ironhacks.com  www.ironhacks.com
# 7537  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...
# 1     http://www.ironhacks.com/preview/Caadiazsi/web...
# 2     http://www.ironhacks.com/preview/Caadiazsi/web...
# 3     http://www.ironhacks.com/preview/Caadiazsi/web...
# 4     http://www.ironhacks.com/preview/Caadiazsi/web...
# ...                                                 ...
# 7533  http://www.ironhacks.com/preview/yaochoal/weba...
# 7534  http://www.ironhacks.com/preview/yaochoal/weba...
# 7535  http://www.ironhacks.com/preview/yaochoal/weba...
# 7536  http://www.ironhacks.com/preview/yaochoal/weba...
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...
#
#                                                   link2 comparison_type  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...            maps
# 1     http://www.ironhacks.com/preview/Joacampora/we...            maps
# 2     http://www.ironhacks.com/preview/Juankmilo97/w...            maps
# 3     http://www.ironhacks.com/preview/Jufcardenasmo...            maps
# 4     http://www.ironhacks.com/preview/casc3798/weba...            maps
# ...                                                 ...             ...
# 7533  http://www.ironhacks.com/preview/olimita/webap...          simple
# 7534  http://www.ironhacks.com/preview/sebcamacho170...          simple
# 7535  http://www.ironhacks.com/preview/serbatero/web...          simple
# 7536  http://www.ironhacks.com/preview/xFortich/weba...          simple
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...          simple
#
#        ssim  features2d  stage
# 0     100.0       100.0      1
# 1      52.9        86.9      1
# 2      37.9        71.0      1
# 3      47.0        90.3      1
# 4      45.4        67.0      1
# ...     ...         ...    ...
# 7533   97.1        81.5      4
# 7534   94.4        71.9      4
# 7535   89.8        83.0      4
# 7536   98.5        84.9      4
# 7537   99.6       100.0      4
#
# [7538 rows x 8 columns]

# %%
ax = sns.lineplot(data=df_no_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Individual Exploration for UNAL 1

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7533  www.ironhacks.com  www.ironhacks.com
# 7534  www.ironhacks.com  www.ironhacks.com
# 7535  www.ironhacks.com  www.ironhacks.com
# 7536  www.ironhacks.com  www.ironhacks.com
# 7537  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...
# 1     http://www.ironhacks.com/preview/Caadiazsi/web...
# 2     http://www.ironhacks.com/preview/Caadiazsi/web...
# 3     http://www.ironhacks.com/preview/Caadiazsi/web...
# 4     http://www.ironhacks.com/preview/Caadiazsi/web...
# ...                                                 ...
# 7533  http://www.ironhacks.com/preview/yaochoal/weba...
# 7534  http://www.ironhacks.com/preview/yaochoal/weba...
# 7535  http://www.ironhacks.com/preview/yaochoal/weba...
# 7536  http://www.ironhacks.com/preview/yaochoal/weba...
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...
#
#                                                   link2 comparison_type  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...            maps
# 1     http://www.ironhacks.com/preview/Joacampora/we...            maps
# 2     http://www.ironhacks.com/preview/Juankmilo97/w...            maps
# 3     http://www.ironhacks.com/preview/Jufcardenasmo...            maps
# 4     http://www.ironhacks.com/preview/casc3798/weba...            maps
# ...                                                 ...             ...
# 7533  http://www.ironhacks.com/preview/olimita/webap...          simple
# 7534  http://www.ironhacks.com/preview/sebcamacho170...          simple
# 7535  http://www.ironhacks.com/preview/serbatero/web...          simple
# 7536  http://www.ironhacks.com/preview/xFortich/weba...          simple
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...          simple
#
#        ssim  features2d  stage link1_change
# 0     100.0       100.0      1    Caadiazsi
# 1      52.9        86.9      1    Caadiazsi
# 2      37.9        71.0      1    Caadiazsi
# 3      47.0        90.3      1    Caadiazsi
# 4      45.4        67.0      1    Caadiazsi
# ...     ...         ...    ...          ...
# 7533   97.1        81.5      4     yaochoal
# 7534   94.4        71.9      4     yaochoal
# 7535   89.8        83.0      4     yaochoal
# 7536   98.5        84.9      4     yaochoal
# 7537   99.6       100.0      4     yaochoal
#
# [7538 rows x 9 columns]

# %%
df_color['link1_change'] = df_color['link1'].str.split('/', expand=True)[4]
df_color['link2_change'] = df_color['link2'].str.split('/', expand=True)[4]
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7533  www.ironhacks.com  www.ironhacks.com
# 7534  www.ironhacks.com  www.ironhacks.com
# 7535  www.ironhacks.com  www.ironhacks.com
# 7536  www.ironhacks.com  www.ironhacks.com
# 7537  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...
# 1     http://www.ironhacks.com/preview/Caadiazsi/web...
# 2     http://www.ironhacks.com/preview/Caadiazsi/web...
# 3     http://www.ironhacks.com/preview/Caadiazsi/web...
# 4     http://www.ironhacks.com/preview/Caadiazsi/web...
# ...                                                 ...
# 7533  http://www.ironhacks.com/preview/yaochoal/weba...
# 7534  http://www.ironhacks.com/preview/yaochoal/weba...
# 7535  http://www.ironhacks.com/preview/yaochoal/weba...
# 7536  http://www.ironhacks.com/preview/yaochoal/weba...
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...
#
#                                                   link2 comparison_type  \
# 0     http://www.ironhacks.com/preview/Caadiazsi/web...            maps
# 1     http://www.ironhacks.com/preview/Joacampora/we...            maps
# 2     http://www.ironhacks.com/preview/Juankmilo97/w...            maps
# 3     http://www.ironhacks.com/preview/Jufcardenasmo...            maps
# 4     http://www.ironhacks.com/preview/casc3798/weba...            maps
# ...                                                 ...             ...
# 7533  http://www.ironhacks.com/preview/olimita/webap...          simple
# 7534  http://www.ironhacks.com/preview/sebcamacho170...          simple
# 7535  http://www.ironhacks.com/preview/serbatero/web...          simple
# 7536  http://www.ironhacks.com/preview/xFortich/weba...          simple
# 7537  http://www.ironhacks.com/preview/yaochoal/weba...          simple
#
#        ssim  features2d  stage link1_change    link2_change
# 0     100.0       100.0      1    Caadiazsi       Caadiazsi
# 1      21.5        40.2      1    Caadiazsi      Joacampora
# 2      16.9        36.1      1    Caadiazsi     Juankmilo97
# 3      35.6        39.2      1    Caadiazsi   Jufcardenasmo
# 4      12.7        33.3      1    Caadiazsi        casc3798
# ...     ...         ...    ...          ...             ...
# 7533   24.7        77.4      4     yaochoal         olimita
# 7534   73.9        61.9      4     yaochoal  sebcamacho1703
# 7535   34.8        79.0      4     yaochoal       serbatero
# 7536   78.7        84.3      4     yaochoal        xFortich
# 7537   99.6       100.0      4     yaochoal        yaochoal
#
# [7538 rows x 10 columns]

# %%
df_color_exp = df_color[df_color['link1_change'] == df_color['link2_change']]
df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']
# Out:
# <ipython-input-9-24f76cc13a19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color['link2_change'] = df_no_color['link2'].str.split('/', expand=True)[4]
df_no_color_exp = df_no_color[df_no_color['link1_change'] == df_no_color['link2_change']]
df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']
# Out:
# <ipython-input-11-23012f618b3e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_no_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
df_color_exp.to_csv("df_color_exp_unal1.csv")

# %store -r ind_group1

pd.set_option('display.max_rows', 2000)

ind_group1['link1_change'] = ind_group1['user1'] 
ind_group1['link2_change'] = ind_group1['user2'] 

df_new = ind_group1[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']]



final_unal1 = df_new.append(df_color_exp[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']], ignore_index = True)


final_unal1.to_csv("final_unal1.csv")

final_unal1_functions = final_unal1[final_unal1['comparison_type'] == 'functions']
final_unal1_complete = final_unal1[final_unal1['comparison_type'] == 'complete']
final_unal1_functions_complete = final_unal1_functions.append(final_unal1_complete, ignore_index = True)
final_unal1_functions_complete.to_csv("final_unal1_functions_complete.csv")

# %%
import networkx as nx
import pandas as pd

df_color_stage1 = df_color[df_color['stage'] == 1]
df_color_stage1 = df_color_stage1[df_color_stage1['link1_change'] != df_color_stage1['link2_change']]
df_color_stage1 = df_color_stage1[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage1,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage1_unal1.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage2 = df_color[df_color['stage'] == 2]
df_color_stage2 = df_color_stage2[df_color_stage2['link1_change'] != df_color_stage2['link2_change']]
df_color_stage2 = df_color_stage2[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage2,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage2_unal1.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage3 = df_color[df_color['stage'] == 3]
df_color_stage3 = df_color_stage3[df_color_stage3['link1_change'] != df_color_stage3['link2_change']]
df_color_stage3 = df_color_stage3[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage3,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage3_unal1.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage4 = df_color[df_color['stage'] == 4]
df_color_stage4 = df_color_stage4[df_color_stage4['stage'] == 4]
df_color_stage4 = df_color_stage4[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage4,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage4_unal1.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage1 = df_color[df_color['stage'] == 1]
df_color_stage1 = df_color_stage1[df_color_stage1['comparison_type'] == "maps"]
df_color_stage1 = df_color_stage1[df_color_stage1['link1_change'] != df_color_stage1['link2_change']]
df_color_stage1 = df_color_stage1[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage1,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage1_unal1_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage1 = df_color[df_color['stage'] == 1]
df_color_stage1 = df_color_stage1[df_color_stage1['comparison_type'] == "maps"]
df_color_stage1 = df_color_stage1[df_color_stage1['link1_change'] != df_color_stage1['link2_change']]
df_color_stage1 = df_color_stage1[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage1,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage1_unal1_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage2 = df_color[df_color['stage'] == 2]
df_color_stage2 = df_color_stage2[df_color_stage2['comparison_type'] == "maps"]
df_color_stage2 = df_color_stage2[df_color_stage2['link1_change'] != df_color_stage2['link2_change']]
df_color_stage2 = df_color_stage2[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage2,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage2_unal1_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage3 = df_color[df_color['stage'] == 3]
df_color_stage3 = df_color_stage3[df_color_stage3['comparison_type'] == 'maps']
df_color_stage3 = df_color_stage3[df_color_stage3['link1_change'] != df_color_stage3['link2_change']]
df_color_stage3 = df_color_stage3[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage3,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage3_unal1_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage4 = df_color[df_color['stage'] == 4]
df_color_stage4 = df_color_stage4[df_color_stage4['comparison_type'] == 'maps']
df_color_stage4 = df_color_stage4[df_color_stage4['stage'] == 4]
df_color_stage4 = df_color_stage4[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage4,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage4_unal1_map.csv')

# %%
# %store final_unal1_functions_complete
# Out:
# Stored 'final_unal1_functions_complete' (DataFrame)
