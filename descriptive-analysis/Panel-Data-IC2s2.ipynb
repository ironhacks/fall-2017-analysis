# %%
import pandas as pd
import numpy as np

df = pd.read_csv("df_color_exp_unal0.csv") 
df1 = pd.read_csv("df_color_exp_unal1.csv") 
df2 = pd.read_csv("df_color_exp_unal2.csv") 
df3 = pd.read_csv("df_color_exp_honors0.csv")

df['group'] = 0
df1['group'] = 1
df2['group'] = 2
df3['group'] = 3

temp = df1.append(df)
temp2 = df2.append(temp)
final = df3.append(temp2)
final['ssim_exp_latest'] = final['ssim_exp'].div(100).round(6)
final.loc[final['ssim_exp_latest'] == 0.0, 'ssim_exp_latest'] = 0.01
final.loc[final['ssim_exp_latest'] == 1.0, 'ssim_exp_latest'] = 0.99
final = final.rename(columns={'comparison_type': 'type', 'stage': 'phase', 'ssim_exp_latest': 'dist_search'})
final.to_csv("final_visual.csv")

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("df_color_exp_unal0.csv") 
df1 = pd.read_csv("df_color_exp_unal1.csv") 
df2 = pd.read_csv("df_color_exp_unal2.csv") 

df['group'] = 0
df1['group'] = 1
df2['group'] = 2

temp = df1.append(df)
final = df2.append(temp)
final['ssim_exp_new'] = final['ssim_exp'].div(100).round(6)

#final[final['ssim_exp_new'] == 1.0, 'ssim_exp_new'] = 0.99
#final[final['ssim_exp_new'] == 0.0, 'ssim_exp_new'] = 0.01
final.to_csv('final_visual.csv')

# create a list of our conditions
conditions = [
    (final['ssim_exp_new'] == 1),
    (final['ssim_exp_new'] == 0)
    ]

# create a list of the values we want to assign for each condition
values = [0.99, 0.01]

# create a new column and use np.select to assign values to it using our lists as arguments
final['tier'] = np.select(conditions, values)
final.to
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-64eb5b6e1892> in <module>
#      29 # create a new column and use np.select to assign values to it using our lists as arguments
#      30 final['tier'] = np.select(conditions, values)
# ---> 31 final.to
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to'

# %%
temp = df.append(df1, ignore_index = True)
df = temp.append(df2, ignore_index = True)
df.to_csv("visual_comp.csv")

# %%
df
# Out:
#      Unnamed: 0          username1          username2  \
# 0             0  www.ironhacks.com  www.ironhacks.com
# 1             9  www.ironhacks.com  www.ironhacks.com
# 2            50  www.ironhacks.com  www.ironhacks.com
# 3            67  www.ironhacks.com  www.ironhacks.com
# 4            84  www.ironhacks.com  www.ironhacks.com
# ..          ...                ...                ...
# 704        5848  www.ironhacks.com  www.ironhacks.com
# 705        5875  www.ironhacks.com  www.ironhacks.com
# 706        5902  www.ironhacks.com  www.ironhacks.com
# 707        5929  www.ironhacks.com  www.ironhacks.com
# 708        5956  www.ironhacks.com  www.ironhacks.com
#
#                                                  link1  \
# 0    http://www.ironhacks.com/preview/BrandonAvilan...
# 1    http://www.ironhacks.com/preview/DaniCastel/we...
# 2    http://www.ironhacks.com/preview/Orloffyeah/we...
# 3    http://www.ironhacks.com/preview/alejosaur/web...
# ...

# %%
import pandas as pd

# %store -r final_unal0_functions_complete
# %store -r final_unal1_functions_complete
# %store -r final_unal2_functions_complete

df = pd.read_csv("final_unal0_functions_complete.csv") 
df1 = pd.read_csv("final_unal1_functions_complete.csv") 
df2 = pd.read_csv("final_unal2_functions_complete.csv") 

df['group'] = 0
df1['group'] = 1
df2['group'] = 2

temp = df1.append(df)
final = df2.append(temp)

final['ssim_exp_latest'] = final['ssim_exp'].div(100).round(6)
final.loc[final['ssim_exp_latest'] == 0.0, 'ssim_exp_latest'] = 0.01
final.loc[final['ssim_exp_latest'] == 1.0, 'ssim_exp_latest'] = 0.99
final = final.rename(columns={'comparison_type': 'type', 'stage': 'phase', 'ssim_exp_latest': 'dist_search'})
df['comparison_type'] = df['comparison_type'].str.replace('complete', 'visual')
df['comparison_type'] = df['comparison_type'].str.replace('functions', 'code')
final.to_csv('final_functions.csv')

# %%
final['ssim_exp_new']
# Out:
# 0      0.318182
# 1      0.272727
# 2      1.000000
# 3      0.484848
# 4      0.360000
#          ...
# 166    0.000000
# 167    0.000000
# 168    0.506000
# 169    0.000000
# 170    0.409000
# Name: ssim_exp_new, Length: 500, dtype: float64

# %%
final
# Out:
#      Unnamed: 0      link1_change      link2_change    ssim_exp  stage  \
# 0             0  diefrodriguezcha  diefrodriguezcha   31.818182      1
# 1             1       adcorredorm       adcorredorm   27.272727      1
# 2             2      DaveValencia      DaveValencia  100.000000      1
# 3             3        pahigueraf        pahigueraf   48.484848      1
# 4             4       jannMorenoJ       jannMorenoJ   36.000000      1
# ..          ...               ...               ...         ...    ...
# 166         166        dieguischa        dieguischa    0.000000      4
# 167         167       jaasuarezvi       jaasuarezvi    0.000000      4
# 168         168         jdsolanos         jdsolanos   50.600000      4
# 169         169          tres-xxx          tres-xxx    0.000000      4
# 170         170     trickyjuggler     trickyjuggler   40.900000      4
#
#     comparison_type  group  ssim_exp_scale  ssim_exp_new
# 0         functions      2             NaN      0.318182
# ...
