# %%
import pandas as pd
import seaborn as sns

data1 = pd.read_csv("../data/all_score_phase1_update.csv")
data2 = pd.read_csv("../data/all_score_phase2_update.csv")
data3 = pd.read_csv("../data/all_score_phase3_update.csv")
data4 = pd.read_csv("../data/all_score_phase4_update.csv")
data5 = pd.read_csv("../data/all_score_phase5_update.csv")
data1['phase'] = 1
data2['phase'] = 2
data3['phase'] = 3
data4['phase'] = 4
data5['phase'] = 5

# %%
df = pd.concat([data1, data2, data3, data4, data5], ignore_index=True)
df
# Out:
#             username  hack id                                      repo name  \
# 0          mdecloedt  honors0        IH-Project-2017-mdecloedt_webapp_phase1
# 1      Jordan-Loeser  honors0    IH-Project-2017-Jordan-Loeser_webapp_phase1
# 2    LukasMMarinovic  honors0  IH-Project-2017-LukasMMarinovic_webapp_phase1
# 3        whipplem123  honors0      IH-Project-2017-whipplem123_webapp_phase1
# 4             SionHu  honors0           IH-Project-2017-SionHu_webapp_phase1
# ..               ...      ...                                            ...
# 535     RafaelCruz15    unal2     IH-Project-2017-RafaelCruz15_webapp_phase5
# 536         gimg1859    unal2         IH-Project-2017-gimg1859_webapp_phase5
# 537      jannMorenoJ    unal2      IH-Project-2017-jannMorenoJ_webapp_phase5
# 538       dahrojasca    unal2       IH-Project-2017-dahrojasca_webapp_phase5
# 539      FredyRosero    unal2      IH-Project-2017-FredyRosero_webapp_phase5
#
#                          time  climate dataset  extra dataset used  \
# 0    Sun Nov  5 20:39:31 2017                0                   0
# 1    Sun Nov  5 20:39:31 2017                0                   0
# 2    Sun Nov  5 20:39:31 2017                0                   0
# 3    Sun Nov  5 20:39:31 2017                0                   0
# 4    Sun Nov  5 20:39:31 2017                0                   0
# ..                        ...              ...                 ...
# 535  Wed Nov 22 08:30:40 2017                0                   0
# 536  Wed Nov 22 08:30:40 2017                0                   0
# 537  Wed Nov 22 08:30:40 2017                0                   0
# 538  Wed Nov 22 08:30:40 2017                0                   0
# 539  Wed Nov 22 08:30:40 2017                1                   1
#
#          extra dataset list  google api  location  using JS  ...  \
# 0                       NaN           0         0         1  ...
# 1                       NaN           1         1         1  ...
# 2                       NaN           0         0         1  ...
# 3                       NaN           0         0         1  ...
# 4                       NaN           1         0         1  ...
# ..                      ...         ...       ...       ...  ...
# 535                     NaN           0         0         1  ...
# 536                     NaN           0         0         1  ...
# 537                     NaN           0         0         1  ...
# 538                     NaN           1         1         1  ...
# 539  Required Weather API,            1         1         1  ...
#
#      combined_infovis_norm  combined_infovis_per  novelty  novelty_normal  \
# 0                13.043478                70.37%        0        0.000000
# 1                13.043478                70.37%        0        0.000000
# 2                 8.695652                40.74%        0        0.000000
# 3                 4.347826                22.22%        0        0.000000
# 4                 0.000000                  0.0%        0        0.000000
# ..                     ...                   ...      ...             ...
# 535               0.000000                  0.0%        0        0.000000
# 536               0.000000                  0.0%        0        0.000000
# 537               0.000000                  0.0%        0        0.000000
# 538              13.043478                59.26%        0        0.000000
# 539              30.434783                77.78%        3        0.666667
#
#      novelty_per novelty_detail  total_raw  total_norm  total_norm_per  phase
# 0           0.0%            NaN          9  179.420290          59.26%      1
# 1           0.0%            NaN         10  194.392041          85.19%      1
# 2           0.0%            NaN          8  175.584075          55.56%      1
# 3           0.0%            NaN          6  158.695652          37.04%      1
# 4           0.0%            NaN          6  158.550725          33.33%      1
# ..           ...            ...        ...         ...             ...    ...
# 535         0.0%            NaN          3  126.666667            0.0%      5
# 536         0.0%            NaN          3  126.666667            0.0%      5
# 537         0.0%            NaN          3  126.666667            0.0%      5
# 538         0.0%            NaN          8  172.417232          48.15%      5
# 539       59.26%  3.0,0.0,0.0,;         17  231.171268          74.07%      5
#
# [540 rows x 41 columns]

# %%
df.loc[df['extra dataset list'].isnull(),['extra dataset list']] = df.loc[df['extra dataset list'].isnull(),'extra dataset list'].apply(lambda x: [])
df
# Out:
#             username  hack id                                      repo name  \
# 0          mdecloedt  honors0        IH-Project-2017-mdecloedt_webapp_phase1
# 1      Jordan-Loeser  honors0    IH-Project-2017-Jordan-Loeser_webapp_phase1
# 2    LukasMMarinovic  honors0  IH-Project-2017-LukasMMarinovic_webapp_phase1
# 3        whipplem123  honors0      IH-Project-2017-whipplem123_webapp_phase1
# 4             SionHu  honors0           IH-Project-2017-SionHu_webapp_phase1
# ..               ...      ...                                            ...
# 535     RafaelCruz15    unal2     IH-Project-2017-RafaelCruz15_webapp_phase5
# 536         gimg1859    unal2         IH-Project-2017-gimg1859_webapp_phase5
# 537      jannMorenoJ    unal2      IH-Project-2017-jannMorenoJ_webapp_phase5
# 538       dahrojasca    unal2       IH-Project-2017-dahrojasca_webapp_phase5
# 539      FredyRosero    unal2      IH-Project-2017-FredyRosero_webapp_phase5
#
#                          time  climate dataset  extra dataset used  \
# 0    Sun Nov  5 20:39:31 2017                0                   0
# 1    Sun Nov  5 20:39:31 2017                0                   0
# 2    Sun Nov  5 20:39:31 2017                0                   0
# 3    Sun Nov  5 20:39:31 2017                0                   0
# 4    Sun Nov  5 20:39:31 2017                0                   0
# ..                        ...              ...                 ...
# 535  Wed Nov 22 08:30:40 2017                0                   0
# 536  Wed Nov 22 08:30:40 2017                0                   0
# 537  Wed Nov 22 08:30:40 2017                0                   0
# 538  Wed Nov 22 08:30:40 2017                0                   0
# 539  Wed Nov 22 08:30:40 2017                1                   1
#
#          extra dataset list  google api  location  using JS  ...  \
# 0                        []           0         0         1  ...
# 1                        []           1         1         1  ...
# 2                        []           0         0         1  ...
# 3                        []           0         0         1  ...
# 4                        []           1         0         1  ...
# ..                      ...         ...       ...       ...  ...
# 535                      []           0         0         1  ...
# 536                      []           0         0         1  ...
# 537                      []           0         0         1  ...
# 538                      []           1         1         1  ...
# 539  Required Weather API,            1         1         1  ...
#
#      combined_infovis_norm  combined_infovis_per  novelty  novelty_normal  \
# 0                13.043478                70.37%        0        0.000000
# 1                13.043478                70.37%        0        0.000000
# 2                 8.695652                40.74%        0        0.000000
# 3                 4.347826                22.22%        0        0.000000
# 4                 0.000000                  0.0%        0        0.000000
# ..                     ...                   ...      ...             ...
# 535               0.000000                  0.0%        0        0.000000
# 536               0.000000                  0.0%        0        0.000000
# 537               0.000000                  0.0%        0        0.000000
# 538              13.043478                59.26%        0        0.000000
# 539              30.434783                77.78%        3        0.666667
#
#      novelty_per novelty_detail  total_raw  total_norm  total_norm_per  phase
# 0           0.0%            NaN          9  179.420290          59.26%      1
# 1           0.0%            NaN         10  194.392041          85.19%      1
# 2           0.0%            NaN          8  175.584075          55.56%      1
# 3           0.0%            NaN          6  158.695652          37.04%      1
# 4           0.0%            NaN          6  158.550725          33.33%      1
# ..           ...            ...        ...         ...             ...    ...
# 535         0.0%            NaN          3  126.666667            0.0%      5
# 536         0.0%            NaN          3  126.666667            0.0%      5
# 537         0.0%            NaN          3  126.666667            0.0%      5
# 538         0.0%            NaN          8  172.417232          48.15%      5
# 539       59.26%  3.0,0.0,0.0,;         17  231.171268          74.07%      5
#
# [540 rows x 41 columns]

# %%
from collections import Counter
df = df[df['extra dataset list'].map(lambda d: len(d)) > 0]
listed = df['extra dataset list'].values.tolist()
x = ''.join(listed)
x = x.split(", ")
countered = Counter(x)
y = countered.most_common()
y
# Out:
# [('Required Weather API', 100),
#  ('New York City Museums', 70),
#  ('New York City Art Galleries', 48),
#  ('Zillow Home Value Searching API', 38),
#  ('Housing New York Units by Building', 25),
#  ('Fire Department Directory for New York State', 24),
#  ('New York State Career Centers', 18),
#  ('New York City Locations Providing Seasonal Flu Vaccinations', 17),
#  ('NYCHA Development Data Book', 13),
#  ('School Safety Report', 12),
#  ('Air Quality', 9),
#  ('Bicycle Routes Across New York State: Map', 9),
#  ('Bank-Owned ATM Locations in New York State', 8),
#  ('New York City Farmers Markets', 8),
#  ('Neighborhood Tabulation Areas', 6),
#  ('New York neighborhood', 6),
#  ('New York Safety', 5),
#  ('Directory Of DCP Offices', 4),
#  ('new york address points', 4),
#  ('Total Housing Units By Occupancy Status And Tenure By Borough', 3),
#  ('Local Area Unemployment Statistics (LAUS) Seasonally Adjusted Data: Beginning 1976',
#   3),
#  ('New York City Leading Causes of Death', 3),
#  ('Alternative Fuel Stations in New York', 3),
#  ('Neighborhood Names GIS', 2),
#  ('New York museum', 2),
#  ('Open.ny.gov API Catalog', 2),
#  ('NYC City Hall Library Catalog', 2),
#  ('New York City Population By Boroughs', 2),
#  ('DOHMH New York City Restaurant Inspection Results', 1),
#  ('New York City Population By Community Districts', 1),
#  ('Facilities Licensed by the Department of Motor Vehicles (DMV)', 1),
#  ('Boardwalk', 1),
#  ('', 1)]

# %%
from itertools import dropwhile
for key, count in dropwhile(lambda key_count: key_count[1] > 10, countered.most_common()):
    del countered[key]
countered
# Out:
# Counter({'Required Weather API': 100,
#          'Fire Department Directory for New York State': 24,
#          'New York State Career Centers': 18,
#          'Zillow Home Value Searching API': 38,
#          'New York City Museums': 70,
#          'School Safety Report': 12,
#          'New York City Art Galleries': 48,
#          'New York City Locations Providing Seasonal Flu Vaccinations': 17,
#          'Housing New York Units by Building': 25,
#          'NYCHA Development Data Book': 13})

# %%
match = [key for key, _ in countered.most_common()]
match
# Out:
# ['Required Weather API',
#  'New York City Museums',
#  'New York City Art Galleries',
#  'Zillow Home Value Searching API',
#  'Housing New York Units by Building',
#  'Fire Department Directory for New York State',
#  'New York State Career Centers',
#  'New York City Locations Providing Seasonal Flu Vaccinations',
#  'NYCHA Development Data Book',
#  'School Safety Report']

# %%
df['match'] = [match for i in df.index]
df
# Out:
# <ipython-input-236-bfc6573834b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['match'] = [match for i in df.index]
#              username  hack id  \
# 5          jmamaril25  honors0
# 20              hihms  honors0
# 24               ko68  honors0
# 27             Nigogu    unal0
# 61          alejosaur    unal1
# ..                ...      ...
# 528         federgolo    unal2
# 531  diefrodriguezcha    unal2
# 532       adcorredorm    unal2
# 534        pahigueraf    unal2
# 539       FredyRosero    unal2
#
#                                           repo name                      time  \
# 5          IH-Project-2017-jmamaril25_webapp_phase1  Sun Nov  5 20:39:31 2017
# 20              IH-Project-2017-hihms_webapp_phase1  Sun Nov  5 20:39:31 2017
# 24               IH-Project-2017-ko68_webapp_phase1  Sun Nov  5 20:39:31 2017
# 27             IH-Project-2017-Nigogu_webapp_phase1  Sun Nov  5 20:39:31 2017
# 61          IH-Project-2017-alejosaur_webapp_phase1  Sun Nov  5 20:39:31 2017
# ..                                              ...                       ...
# 528         IH-Project-2017-federgolo_webapp_phase5  Wed Nov 22 08:30:40 2017
# 531  IH-Project-2017-diefrodriguezcha_webapp_phase5  Wed Nov 22 08:30:40 2017
# 532       IH-Project-2017-adcorredorm_webapp_phase5  Wed Nov 22 08:30:40 2017
# 534        IH-Project-2017-pahigueraf_webapp_phase5  Wed Nov 22 08:30:40 2017
# 539       IH-Project-2017-FredyRosero_webapp_phase5  Wed Nov 22 08:30:40 2017
#
#      climate dataset  extra dataset used  \
# 5                  1                   1
# 20                 0                   1
# 24                 1                   1
# 27                 1                   1
# 61                 0                   1
# ..               ...                 ...
# 528                1                   4
# 531                1                   4
# 532                1                   2
# 534                1                   7
# 539                1                   1
#
#                                     extra dataset list  google api  location  \
# 5                               Required Weather API,            1         1
# 20                              Required Weather API,            0         1
# 24                              Required Weather API,            1         1
# 27                              Required Weather API,            1         1
# 61        Bank-Owned ATM Locations in New York State,            1         1
# ..                                                 ...         ...       ...
# 528  New York City Locations Providing Seasonal Flu...           0         1
# 531  New York City Art Galleries, New York City Pop...           0         1
# 532    Required Weather API, new york address points,            1         1
# 534  New York City Art Galleries, new york address ...           1         1
# 539                             Required Weather API,            1         1
#
#      using JS  ...  combined_infovis_per  novelty  novelty_normal  \
# 5           1  ...                70.37%        3        0.666667
# 20          1  ...                70.37%        7        1.555556
# 24          1  ...                40.74%        3        0.666667
# 27          1  ...                66.67%        3        0.666667
# 61          1  ...                66.67%        2        0.444444
# ..        ...  ...                   ...      ...             ...
# 528         1  ...                44.44%       20        4.444444
# 531         1  ...                 96.3%       24        5.333333
# 532         1  ...                77.78%        6        1.333333
# 534         1  ...                70.37%       34        7.555556
# 539         1  ...                77.78%        3        0.666667
#
#      novelty_per                                     novelty_detail total_raw  \
# 5         88.89%                                      3.0,0.0,0.0,;        15
# 20         96.3%                                      3.0,3.0,1.0,;        17
# 24        88.89%                                      3.0,0.0,0.0,;        15
# 27         96.3%                                      3.0,0.0,0.0,;        15
# 61         96.3%                                      2.0,0.0,0.0,;        13
# ..           ...                                                ...       ...
# 528       81.48%  1.0,1.0,2.0,;3.0,0.0,2.0,;3.0,2.0,2.0,;1.0,1.0...        29
# 531       85.19%  1.0,1.0,2.0,;1.0,0.0,0.0,;3.0,0.0,0.0,;1.0,1.0...        64
# 532       70.37%                         3.0,0.0,0.0,;3.0,0.0,0.0,;        21
# 534        96.3%  1.0,1.0,2.0,;3.0,0.0,0.0,;3.0,2.0,2.0,;1.0,1.0...        50
# 539       59.26%                                      3.0,0.0,0.0,;        17
#
#      total_norm  total_norm_per  phase  \
# 5    216.753623          92.59%      1
# 20   195.620040          88.89%      1
# 24   217.353746           96.3%      1
# 27   214.684658           96.3%      1
# 61   202.727053          85.19%      1
# ..          ...             ...    ...
# 528  192.154875          55.56%      5
# 531  463.492473           96.3%      5
# 532  238.690502          77.78%      5
# 534  258.791969          81.48%      5
# 539  231.171268          74.07%      5
#
#                                                  match
# 5    [Required Weather API, New York City Museums, ...
# 20   [Required Weather API, New York City Museums, ...
# 24   [Required Weather API, New York City Museums, ...
# 27   [Required Weather API, New York City Museums, ...
# 61   [Required Weather API, New York City Museums, ...
# ..                                                 ...
# 528  [Required Weather API, New York City Museums, ...
# 531  [Required Weather API, New York City Museums, ...
# 532  [Required Weather API, New York City Museums, ...
# 534  [Required Weather API, New York City Museums, ...
# 539  [Required Weather API, New York City Museums, ...
#
# [173 rows x 42 columns]

# %%
df['fail'] = [list(set(a).intersection(b)) for a, b in zip(df['extra dataset list'], df.match)]
df
# Out:
# <ipython-input-237-fdca6896a0b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fail'] = [list(set(a).intersection(b)) for a, b in zip(df['extra dataset list'], df.match)]
#              username  hack id  \
# 5          jmamaril25  honors0
# 20              hihms  honors0
# 24               ko68  honors0
# 27             Nigogu    unal0
# 61          alejosaur    unal1
# ..                ...      ...
# 528         federgolo    unal2
# 531  diefrodriguezcha    unal2
# 532       adcorredorm    unal2
# 534        pahigueraf    unal2
# 539       FredyRosero    unal2
#
#                                           repo name                      time  \
# 5          IH-Project-2017-jmamaril25_webapp_phase1  Sun Nov  5 20:39:31 2017
# 20              IH-Project-2017-hihms_webapp_phase1  Sun Nov  5 20:39:31 2017
# 24               IH-Project-2017-ko68_webapp_phase1  Sun Nov  5 20:39:31 2017
# 27             IH-Project-2017-Nigogu_webapp_phase1  Sun Nov  5 20:39:31 2017
# 61          IH-Project-2017-alejosaur_webapp_phase1  Sun Nov  5 20:39:31 2017
# ..                                              ...                       ...
# 528         IH-Project-2017-federgolo_webapp_phase5  Wed Nov 22 08:30:40 2017
# 531  IH-Project-2017-diefrodriguezcha_webapp_phase5  Wed Nov 22 08:30:40 2017
# 532       IH-Project-2017-adcorredorm_webapp_phase5  Wed Nov 22 08:30:40 2017
# 534        IH-Project-2017-pahigueraf_webapp_phase5  Wed Nov 22 08:30:40 2017
# 539       IH-Project-2017-FredyRosero_webapp_phase5  Wed Nov 22 08:30:40 2017
#
#      climate dataset  extra dataset used  \
# 5                  1                   1
# 20                 0                   1
# 24                 1                   1
# 27                 1                   1
# 61                 0                   1
# ..               ...                 ...
# 528                1                   4
# 531                1                   4
# 532                1                   2
# 534                1                   7
# 539                1                   1
#
#                                     extra dataset list  google api  location  \
# 5                               Required Weather API,            1         1
# 20                              Required Weather API,            0         1
# 24                              Required Weather API,            1         1
# 27                              Required Weather API,            1         1
# 61        Bank-Owned ATM Locations in New York State,            1         1
# ..                                                 ...         ...       ...
# 528  New York City Locations Providing Seasonal Flu...           0         1
# 531  New York City Art Galleries, New York City Pop...           0         1
# 532    Required Weather API, new york address points,            1         1
# 534  New York City Art Galleries, new york address ...           1         1
# 539                             Required Weather API,            1         1
#
#      using JS  ...  novelty  novelty_normal  novelty_per  \
# 5           1  ...        3        0.666667       88.89%
# 20          1  ...        7        1.555556        96.3%
# 24          1  ...        3        0.666667       88.89%
# 27          1  ...        3        0.666667        96.3%
# 61          1  ...        2        0.444444        96.3%
# ..        ...  ...      ...             ...          ...
# 528         1  ...       20        4.444444       81.48%
# 531         1  ...       24        5.333333       85.19%
# 532         1  ...        6        1.333333       70.37%
# 534         1  ...       34        7.555556        96.3%
# 539         1  ...        3        0.666667       59.26%
#
#                                         novelty_detail  total_raw  total_norm  \
# 5                                        3.0,0.0,0.0,;         15  216.753623
# 20                                       3.0,3.0,1.0,;         17  195.620040
# 24                                       3.0,0.0,0.0,;         15  217.353746
# 27                                       3.0,0.0,0.0,;         15  214.684658
# 61                                       2.0,0.0,0.0,;         13  202.727053
# ..                                                 ...        ...         ...
# 528  1.0,1.0,2.0,;3.0,0.0,2.0,;3.0,2.0,2.0,;1.0,1.0...         29  192.154875
# 531  1.0,1.0,2.0,;1.0,0.0,0.0,;3.0,0.0,0.0,;1.0,1.0...         64  463.492473
# 532                         3.0,0.0,0.0,;3.0,0.0,0.0,;         21  238.690502
# 534  1.0,1.0,2.0,;3.0,0.0,0.0,;3.0,2.0,2.0,;1.0,1.0...         50  258.791969
# 539                                      3.0,0.0,0.0,;         17  231.171268
#
#      total_norm_per  phase                                              match  \
# 5            92.59%      1  [Required Weather API, New York City Museums, ...
# 20           88.89%      1  [Required Weather API, New York City Museums, ...
# 24            96.3%      1  [Required Weather API, New York City Museums, ...
# 27            96.3%      1  [Required Weather API, New York City Museums, ...
# 61           85.19%      1  [Required Weather API, New York City Museums, ...
# ..              ...    ...                                                ...
# 528          55.56%      5  [Required Weather API, New York City Museums, ...
# 531           96.3%      5  [Required Weather API, New York City Museums, ...
# 532          77.78%      5  [Required Weather API, New York City Museums, ...
# 534          81.48%      5  [Required Weather API, New York City Museums, ...
# 539          74.07%      5  [Required Weather API, New York City Museums, ...
#
#      fail
# 5      []
# 20     []
# 24     []
# 27     []
# 61     []
# ..    ...
# 528    []
# 531    []
# 532    []
# 534    []
# 539    []
#
# [173 rows x 43 columns]

# %%
df['extra dataset list']
# Out:
# 5                                 Required Weather API,
# 20                                Required Weather API,
# 24                                Required Weather API,
# 27                                Required Weather API,
# 61          Bank-Owned ATM Locations in New York State,
#                              ...
# 528    New York City Locations Providing Seasonal Flu...
# 531    New York City Art Galleries, New York City Pop...
# 532      Required Weather API, new york address points,
# 534    New York City Art Galleries, new york address ...
# 539                               Required Weather API,
# Name: extra dataset list, Length: 173, dtype: object

# %%
df['match']
# Out:
# 5      [Required Weather API, New York City Museums, ...
# 20     [Required Weather API, New York City Museums, ...
# 24     [Required Weather API, New York City Museums, ...
# 27     [Required Weather API, New York City Museums, ...
# 61     [Required Weather API, New York City Museums, ...
#                              ...
# 528    [Required Weather API, New York City Museums, ...
# 531    [Required Weather API, New York City Museums, ...
# 532    [Required Weather API, New York City Museums, ...
# 534    [Required Weather API, New York City Museums, ...
# 539    [Required Weather API, New York City Museums, ...
# Name: match, Length: 173, dtype: object

# %%
df.to_csv("scores.csv")

# %%
import itertools
def jaccard_similarity(x, y):
    """ returns the jaccard similarity between two lists """
    intersection_cardinality = len(set.intersection(*[set(x), set(y)]))
    union_cardinality = len(set.union(*[set(x), set(y)]))
    if union_cardinality == 0:
        return 1
    return intersection_cardinality/float(union_cardinality)

wordings_users = list(zip(df["extra dataset list"], df["username"], df["phase"]))

result = []

# create list of all possible combinations between sets of (wording, user) and loop through them
for item in list(itertools.combinations(wordings_users, 2)):
    similarity = jaccard_similarity(item[0][0], item[1][0])
    data = {"user1": item[0][1], "user2": item[1][1], "user1_phase": item[0][2], "user2_phase": item[1][2], "similarity": similarity}
    result.append(data)

final = pd.DataFrame(result)
final.to_csv("data-analysis.csv")

# %%
final['temp'] = abs(final['user1_phase'] - final['user2_phase'])
final = final[final['temp'] == 1]
final = final[final['user1'] == final['user2']]
final['stage'] = final['user1_phase']
final['dist_search'] = 1 - final['similarity']
final['type'] = 'data'
final.to_csv("temp.csv")

# %%
sns.lineplot(data=final, x="stage", y="dist_search")
# Out:
# <AxesSubplot:xlabel='stage', ylabel='dist_search'>

# %%
final
# Out:
#                   user1            user2  user1_phase  user2_phase  \
# 107           mdecloedt        mdecloedt            1            2
# 646       Jordan-Loeser    Jordan-Loeser            1            2
# 1184    LukasMMarinovic  LukasMMarinovic            1            2
# 1721        whipplem123      whipplem123            1            2
# 2257             SionHu           SionHu            1            2
# ...                 ...              ...          ...          ...
# 139309     RafaelCruz15     RafaelCruz15            4            5
# 139421         gimg1859         gimg1859            4            5
# 139532      jannMorenoJ      jannMorenoJ            4            5
# 139642       dahrojasca       dahrojasca            4            5
# 139751      FredyRosero      FredyRosero            4            5
#
#         similarity  temp  stage  dist_search  type
# 107            0.0     1      1          1.0  data
# 646            0.0     1      1          1.0  data
# 1184           1.0     1      1          0.0  data
# 1721           1.0     1      1          0.0  data
# 2257           1.0     1      1          0.0  data
# ...            ...   ...    ...          ...   ...
# 139309         1.0     1      4          0.0  data
# 139421         1.0     1      4          0.0  data
# 139532         1.0     1      4          0.0  data
# 139642         1.0     1      4          0.0  data
# 139751         0.0     1      4          1.0  data
#
# [431 rows x 9 columns]
