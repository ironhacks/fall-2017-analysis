# %% [markdown]
# ## This notebook is to do a preliminary exploration on the data quality generated from SSIM to determine the optimum research question.

# %%
import pandas as pd
import seaborn as sns

# UNAL 0 Phase 4 - 5 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 4 - 5 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 3 - 4 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 3 - 4 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 2 - 3 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 2 - 3 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 1 - 2 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %%
# UNAL 0 Phase 1 - 2 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))

# %% [markdown]
# ## Construct panel data for Green IronHack with colors

# %%
import pandas as pd
import seaborn as sns
df_12 = pd.read_csv("../data/GreenIronHack-Phase1-GreenIronHack-Phase2/GreenIronHack-Phase1-GreenIronHack-Phase2–raw-results.csv")
df_23 = pd.read_csv("../data/GreenIronHack-Phase2-GreenIronHack-Phase3/GreenIronHack-Phase2-GreenIronHack-Phase3–raw-results.csv")
df_34 = pd.read_csv("../data/GreenIronHack-Phase3-GreenIronHack-Phase4/GreenIronHack-Phase3-GreenIronHack-Phase4–raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3

# %%
df_color = pd.concat([df_12, df_23, df_34], ignore_index=True)
df_color
# Out:
#       username1      username2  \
# 0     huayifang  megamindhenry
# 1     huayifang       lostkuma
# 2     huayifang  meetalivaidya
# 3     huayifang          pjt90
# 4     huayifang     pmittal115
# ...         ...            ...
# 4146      wluan    tanmayee123
# 4147      wluan      taycurt17
# 4148      wluan       lostkuma
# 4149      wluan         rawgit
# 4150      wluan        sauravn
#
#                                                   link1  \
# 0     http://phase1-greenironhack-huayifang.herokuap...
# 1     http://phase1-greenironhack-huayifang.herokuap...
# 2     http://phase1-greenironhack-huayifang.herokuap...
# 3     http://phase1-greenironhack-huayifang.herokuap...
# 4     http://phase1-greenironhack-huayifang.herokuap...
# ...                                                 ...
# 4146   http://greenironhack-wluan.herokuapp.com/d3.html
# 4147   http://greenironhack-wluan.herokuapp.com/d3.html
# 4148   http://greenironhack-wluan.herokuapp.com/d3.html
# 4149   http://greenironhack-wluan.herokuapp.com/d3.html
# 4150   http://greenironhack-wluan.herokuapp.com/d3.html
#
#                                                   link2 comparison_type  ssim  \
# 0     http://greenironhack2016.herokuapp.com/p2-Mega...            maps  56.7
# 1     http://greenironhack2016.herokuapp.com/p2-lost...            maps  60.3
# 2     http://greenironhack2016.herokuapp.com/p2-meet...            maps  16.9
# 3     http://greenironhack2016.herokuapp.com/p2-pjt9...            maps  63.7
# 4     http://greenironhack2016.herokuapp.com/p2-pmit...            maps  79.8
# ...                                                 ...             ...   ...
# 4146  http://greenironhack-tanmayee123-2016.herokuap...          simple   5.7
# 4147  http://greenironhack-taycurt17-2016.herokuapp....          simple  10.7
# 4148                     http://lostkuma.herokuapp.com/          simple  12.3
# 4149  http://rawgit.com/priyankjain/2016-purdue-iron...          simple   3.0
# 4150          http://sauravn-application.herokuapp.com/          simple   8.7
#
#       features2d  stage
# 0           64.9      1
# 1           52.9      1
# 2           69.3      1
# 3           62.0      1
# 4           97.0      1
# ...          ...    ...
# 4146       100.0      3
# 4147       100.0      3
# 4148       100.0      3
# 4149       100.0      3
# 4150       100.0      3
#
# [4151 rows x 8 columns]

# %%
sns.lineplot(data=df_color, x='stage', y='ssim', hue='comparison_type')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-3-d30bc54d8019> in <module>
# ----> 1 sns.lineplot(data=df_color, x='stage', y='ssim', hue='comparison_type')
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     701     p._attach(ax)
#     702
# --> 703     p.plot(ax, kwargs)
#     704     return ax
#     705
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in plot(self, ax, kws)
#     497                     err = "estimator must be None when specifying units"
#     498                     raise ValueError(err)
# --> 499                 x, y, y_ci = self.aggregate(y, x, u)
#     500             else:
#     501                 y_ci = None
#
# /usr/local/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in aggregate(self, vals, grouper, units)
#     399         # Group and get the aggregation estimate
#     400         grouped = vals.groupby(grouper, sort=self.sort)
# --> 401         est = grouped.agg(func)
#     402
#     403         # Exit early if we don't want a confidence interval
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     239
#     240         if isinstance(func, str):
# --> 241             return getattr(self, func)(*args, **kwargs)
#     242
#     243         elif isinstance(func, abc.Iterable):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %% [markdown]
# ## Construct panel data for Green IronHacks with no colors

# %%
df_45 = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–no-color-raw-results.csv")
df_34 = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–no-color-raw-results.csv")
df_23 = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–no-color-raw-results.csv")
df_12 = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–no-color-raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_no_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_no_color

# %%
ax = sns.lineplot(data=df_no_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Individual Exploration for Green IronHacks

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color

# %%
df_color['link1_change'] = df_color['link1'].str.split('-', expand=True)[1]
df_color['link2_change'] = df_color['link2'].str.split('-', expand=True)[1]
df_color

# %%
pd.set_option('display.max_rows', None)
df_color = df_color[df_color['username1'] == df_color['username2']]
df_color['ssim']
# Out:
# 9        50.7
# 19       77.7
# 29       42.3
# 32       41.5
# 46      100.0
# 55      100.0
# 64      100.0
# 70      100.0
# 93       90.3
# 127       0.0
# 155      27.8
# 183      52.0
# 212       0.0
# 240      50.0
# 269     100.0
# 298      99.6
# 329      53.6
# 357       0.0
# 386     100.0
# 414     100.0
# 419     100.0
# 447       0.0
# 477       0.0
# 497       0.0
# 535     100.0
# 565      83.7
# 580      63.7
# 621      72.0
# 650       0.0
# 678      45.6
# 706       0.0
# 763     100.0
# 793      78.5
# 799     100.0
# 821      90.3
# 854       0.0
# 881      27.8
# 908      52.0
# 936       0.0
# 963      66.5
# 991     100.0
# 1019    100.0
# 1049     82.9
# 1076      0.0
# 1103    100.0
# 1130    100.0
# 1135    100.0
# 1162      0.0
# 1191      0.0
# 1210      0.0
# 1247    100.0
# 1276     83.7
# 1290     57.0
# 1330     72.0
# 1358     16.7
# 1385     45.6
# 1412      0.0
# 1469    100.0
# 1473     68.3
# 1479     81.1
# 1488     70.0
# 1498     75.4
# 1507     80.2
# 1524     78.5
# 1536     99.9
# 1543     99.9
# 1544     98.6
# 1552     98.5
# 1553     99.6
# 1574     99.9
# 1575     99.8
# 1576     99.9
# 1577     99.9
# 1578     99.8
# 1583     99.9
# 1584     99.8
# 1585     99.9
# 1586     99.9
# 1587     99.9
# 1592     99.9
# 1593     99.9
# 1594     99.8
# 1595     99.8
# 1596     99.8
# 1601     99.9
# 1602     99.9
# 1603     99.8
# 1604     99.8
# 1605     99.8
# 1622      0.0
# 1642      0.1
# 1675     82.9
# 1687    100.0
# 1712    100.0
# 1785     78.7
# 1811     47.0
# 1836     99.3
# 1861    100.0
# 1887    100.0
# 1912    100.0
# 1937     99.6
# 1962    100.0
# 1988    100.0
# 2013     86.9
# 2038     83.4
# 2063     80.6
# 2088     85.9
# 2138     95.3
# 2163    100.0
# 2188     77.5
# 2213      0.0
# 2238      2.9
# 2268      0.0
# 2317     99.1
# 2329    100.0
# 2418     78.7
# 2441     47.0
# 2464     99.6
# 2487    100.0
# 2511    100.0
# 2534    100.0
# 2557     99.6
# 2580    100.0
# 2604    100.0
# 2627     87.4
# 2650    100.0
# 2673     93.4
# 2696     85.9
# 2742     79.6
# 2765    100.0
# 2789     97.0
# 2812      3.0
# 2838     41.3
# 2859     93.7
# 2895     96.2
# 2923    100.0
# 2940     99.9
# 2941     98.6
# 2962     98.6
# 2963     99.6
# 3044     99.9
# 3045     99.9
# 3046     99.8
# 3047     99.9
# 3048     99.8
# 3066     99.9
# 3067     99.9
# 3068     99.8
# 3069     99.9
# 3070     99.8
# 3088     99.9
# 3089     99.8
# 3090     99.9
# 3091     99.8
# 3092     99.9
# 3110     99.9
# 3111     99.9
# 3112     99.9
# 3113     99.9
# 3114     99.8
# 3132     99.8
# 3133     99.8
# 3134     99.9
# 3135     99.8
# 3136    100.0
# 3138     57.8
# 3209     54.0
# 3233     49.3
# 3257     97.5
# 3281     94.4
# 3353    100.0
# 3387     59.6
# 3447    100.0
# 3496     94.9
# 3520     11.2
# 3568      5.6
# 3596     94.7
# 3638    100.0
# 3662     24.5
# 3690     57.8
# 3735     51.5
# 3757     98.1
# 3779     94.4
# 3843    100.0
# 3875     59.6
# 3929    100.0
# 3974     81.9
# 3996     66.4
# 4040      5.6
# 4066     95.5
# 4104    100.0
# 4126      8.1
# Name: ssim, dtype: object

# %%
df_color['ssim'] = df_color['ssim'].astype(str).astype(int)
print(df_color['ssim'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5525b429ae47> in <module>
# ----> 1 df_color['ssim'] = df_color['ssim'].astype(str).astype(int)
#       2 print(df_color['ssim'])
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '50.7'

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color['link2_change'] = df_no_color['link2'].str.split('/', expand=True)[4]
df_no_color_exp = df_no_color[df_no_color['link1_change'] == df_no_color['link2_change']]
df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_no_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)
