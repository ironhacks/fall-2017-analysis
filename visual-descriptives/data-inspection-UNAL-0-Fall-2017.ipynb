# %% [markdown]
# ## Descriptive Analysis for UNAL 0 Fall 2017

# %%
import pandas as pd
import seaborn as sns

# UNAL 0 Phase 4 - 5 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  208.000000       208.000000        count    16.000000
# 1       mean   22.891827        42.881250         mean    77.762500
# 2        std   15.794736        22.564745          std    20.697693
# 3        min    2.700000        15.600000          min    48.900000
# 4        25%   17.500000        31.300000          25%    56.700000
# 5        50%   21.550000        35.100000          50%    79.900000
# 6        75%   24.425000        41.500000          75%   100.000000
# 7        max  100.000000       100.000000          max   100.000000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0               16.0          count     609.000000           609.000000
# 1              100.0           mean      35.781938            79.223645
# 2                0.0            std      26.681538            27.456645
# ...

# %%
# UNAL 0 Phase 4 - 5 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  208.000000       208.000000        count    16.000000
# 1       mean   31.361058        72.489423         mean    92.800000
# 2        std   16.944937        17.922991          std     8.427099
# 3        min    1.800000        33.900000          min    75.800000
# 4        25%   21.775000        61.450000          25%    87.100000
# 5        50%   27.150000        76.150000          50%    96.200000
# 6        75%   35.225000        83.650000          75%   100.000000
# 7        max  100.000000       100.000000          max   100.000000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0               16.0          count     609.000000           609.000000
# 1              100.0           mean      57.688670            91.046962
# 2                0.0            std      23.311256            12.577959
# ...

# %%
# UNAL 0 Phase 3 - 4 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  221.000000       221.000000        count    20.000000
# 1       mean   25.480543        41.644344         mean    86.895000
# 2        std   11.103977        22.014527          std     8.236854
# 3        min    3.000000         0.800000          min    71.400000
# 4        25%   20.400000        30.100000          25%    83.325000
# 5        50%   27.600000        37.100000          50%    88.200000
# 6        75%   32.200000        42.700000          75%    95.000000
# 7        max   68.700000       100.000000          max    96.500000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0          20.000000          count      609.00000           609.000000
# 1          96.140000           mean       35.20509            69.421675
# 2          10.936968            std       19.07718            29.508545
# ...

# %%
# UNAL 0 Phase 3 - 4 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  221.000000       221.000000        count    20.000000
# 1       mean   44.181448        75.906335         mean    90.385000
# 2        std   20.969364        16.180141          std     9.709479
# 3        min   12.400000        25.000000          min    69.300000
# 4        25%   29.600000        66.900000          25%    88.000000
# 5        50%   38.500000        80.600000          50%    93.950000
# 6        75%   50.800000        85.600000          75%    97.000000
# 7        max   97.500000       100.000000          max   100.000000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0          20.000000          count     609.000000           609.000000
# 1          94.800000           mean      60.614778            87.821511
# 2          15.669615            std      22.914685            13.166354
# ...

# %%
# UNAL 0 Phase 2 - 3 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  136.000000       136.000000        count     5.000000
# 1       mean   35.609559        45.480147         mean    79.580000
# 2        std   13.760609        21.698468          std     3.279787
# 3        min   10.200000         7.900000          min    76.100000
# 4        25%   26.375000        33.900000          25%    76.100000
# 5        50%   32.800000        39.200000          50%    81.000000
# 6        75%   42.600000        46.475000          75%    81.500000
# 7        max   98.200000       100.000000          max    83.200000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0           5.000000          count     377.000000           377.000000
# 1          79.960000           mean      42.424403            69.855968
# 2          16.561491            std      20.242165            29.170559
# ...

# %%
# UNAL 0 Phase 2 - 3 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  136.000000       136.000000        count     5.000000
# 1       mean   50.458824        80.389706         mean    79.240000
# 2        std   14.314336        11.249746          std     1.768615
# 3        min   22.700000        46.300000          min    77.600000
# 4        25%   40.875000        76.200000          25%    77.600000
# 5        50%   48.900000        81.900000          50%    79.200000
# 6        75%   60.800000        87.225000          75%    80.000000
# 7        max   87.700000       100.000000          max    81.800000
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0           5.000000          count     377.000000           377.000000
# 1          72.800000           mean      63.739257            87.605040
# 2          22.857384            std      21.088042            13.932877
# ...

# %%
# UNAL 0 Phase 1 - 2 Raw Results with Colors

df = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  152.000000       152.000000        count          0.0
# 1       mean   27.282895        44.893421         mean          NaN
# 2        std   18.300891        18.070992          std          NaN
# 3        min    5.000000        16.600000          min          NaN
# 4        25%    9.100000        34.800000          25%          NaN
# 5        50%   28.700000        38.050000          50%          NaN
# 6        75%   39.700000        44.750000          75%          NaN
# 7        max   94.000000       100.000000          max          NaN
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0                0.0          count     377.000000           377.000000
# 1                NaN           mean      43.398408            72.798143
# 2                NaN            std      21.426487            27.882881
# ...

# %%
# UNAL 0 Phase 1 - 2 Raw Results without Colors

df = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–no-color-raw-results.csv")
df_maps = df[df['comparison_type'] == 'maps']
df_charts = df[df['comparison_type'] == 'charts']
df_complete = df[df['comparison_type'] == 'complete']
df_simple = df[df['comparison_type'] == 'simple']

print (pd.concat([
    df_maps.describe().reset_index().add_suffix('_maps'),
    df_charts.describe().reset_index().add_suffix('_charts'),
    df_complete.describe().reset_index().add_suffix('_complete'),
    df_simple.describe().reset_index().add_suffix('_simple')
  ], axis=1))
# Out:
#   index_maps   ssim_maps  features2d_maps index_charts  ssim_charts  \
# 0      count  152.000000       152.000000        count          0.0
# 1       mean   61.231579        78.765132         mean          NaN
# 2        std   20.573201         8.185873          std          NaN
# 3        min   23.900000        47.600000          min          NaN
# 4        25%   44.550000        74.050000          25%          NaN
# 5        50%   55.400000        79.450000          50%          NaN
# 6        75%   79.500000        84.100000          75%          NaN
# 7        max   94.900000        96.000000          max          NaN
#
#    features2d_charts index_complete  ssim_complete  features2d_complete  \
# 0                0.0          count     377.000000           377.000000
# 1                NaN           mean      70.568435            87.675332
# 2                NaN            std      17.577336            13.729825
# ...

# %% [markdown]
# ## Construct panel data for UNAL 2 with colors

# %%
df_45 = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–raw-results.csv")
df_34 = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–raw-results.csv")
df_23 = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–raw-results.csv")
df_12 = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 4697  www.ironhacks.com  www.ironhacks.com
# 4698  www.ironhacks.com  www.ironhacks.com
# 4699  www.ironhacks.com  www.ironhacks.com
# 4700  www.ironhacks.com  www.ironhacks.com
# 4701  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/BrandonAvilan...
# 1     http://www.ironhacks.com/preview/BrandonAvilan...
# 2     http://www.ironhacks.com/preview/BrandonAvilan...
# 3     http://www.ironhacks.com/preview/BrandonAvilan...
# 4     http://www.ironhacks.com/preview/BrandonAvilan...
# ...                                                 ...
# ...

# %%
ax = sns.lineplot(data=df_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Construct panel data for UNAL 2 with no colors

# %%
df_45 = pd.read_csv("../data/Unal-0-Phase-4-_Unal-0-Phase-5–no-color-raw-results.csv")
df_34 = pd.read_csv("../data/Unal-0-Phase-3-_Unal-0-Phase-4–no-color-raw-results.csv")
df_23 = pd.read_csv("../data/Unal-0-Phase-2-_Unal-0-Phase-3–no-color-raw-results.csv")
df_12 = pd.read_csv("../data/Unal-0-Phase-1-_Unal-0-Phase-2–no-color-raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_no_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 4697  www.ironhacks.com  www.ironhacks.com
# 4698  www.ironhacks.com  www.ironhacks.com
# 4699  www.ironhacks.com  www.ironhacks.com
# 4700  www.ironhacks.com  www.ironhacks.com
# 4701  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/BrandonAvilan...
# 1     http://www.ironhacks.com/preview/BrandonAvilan...
# 2     http://www.ironhacks.com/preview/BrandonAvilan...
# 3     http://www.ironhacks.com/preview/BrandonAvilan...
# 4     http://www.ironhacks.com/preview/BrandonAvilan...
# ...                                                 ...
# ...

# %%
ax = sns.lineplot(data=df_no_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Individual Exploration for UNAL 0

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 4697  www.ironhacks.com  www.ironhacks.com
# 4698  www.ironhacks.com  www.ironhacks.com
# 4699  www.ironhacks.com  www.ironhacks.com
# 4700  www.ironhacks.com  www.ironhacks.com
# 4701  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/BrandonAvilan...
# 1     http://www.ironhacks.com/preview/BrandonAvilan...
# 2     http://www.ironhacks.com/preview/BrandonAvilan...
# 3     http://www.ironhacks.com/preview/BrandonAvilan...
# 4     http://www.ironhacks.com/preview/BrandonAvilan...
# ...                                                 ...
# ...

# %%
df_color['link1_change'] = df_color['link1'].str.split('/', expand=True)[4]
df_color['link2_change'] = df_color['link2'].str.split('/', expand=True)[4]
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 4697  www.ironhacks.com  www.ironhacks.com
# 4698  www.ironhacks.com  www.ironhacks.com
# 4699  www.ironhacks.com  www.ironhacks.com
# 4700  www.ironhacks.com  www.ironhacks.com
# 4701  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/BrandonAvilan...
# 1     http://www.ironhacks.com/preview/BrandonAvilan...
# 2     http://www.ironhacks.com/preview/BrandonAvilan...
# 3     http://www.ironhacks.com/preview/BrandonAvilan...
# 4     http://www.ironhacks.com/preview/BrandonAvilan...
# ...                                                 ...
# ...

# %%
df_color_exp = df_color[df_color['link1_change'] == df_color['link2_change']]
df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']
# Out:
# <ipython-input-17-24f76cc13a19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color['link2_change'] = df_no_color['link2'].str.split('/', expand=True)[4]
df_no_color_exp = df_no_color[df_no_color['link1_change'] == df_no_color['link2_change']]
df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']
# Out:
# <ipython-input-19-23012f618b3e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_no_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
# save variables
import pandas as pd

df_color_exp.to_csv("df_color_exp_unal0.csv")
df = pd.read_csv("df_color_exp_honors0.csv")
df_color_exp = df_color_exp.append(df)
df_color_exp
# Out:
#              username1          username2  \
# 0    www.ironhacks.com  www.ironhacks.com
# 9    www.ironhacks.com  www.ironhacks.com
# 50   www.ironhacks.com  www.ironhacks.com
# 67   www.ironhacks.com  www.ironhacks.com
# 84   www.ironhacks.com  www.ironhacks.com
# ..                 ...                ...
# 261  www.ironhacks.com  www.ironhacks.com
# 262  www.ironhacks.com  www.ironhacks.com
# 263  www.ironhacks.com  www.ironhacks.com
# 264  www.ironhacks.com  www.ironhacks.com
# 265  www.ironhacks.com  www.ironhacks.com
#
#                                                  link1  \
# 0    http://www.ironhacks.com/preview/BrandonAvilan...
# 9    http://www.ironhacks.com/preview/DaniCastel/we...
# 50   http://www.ironhacks.com/preview/Orloffyeah/we...
# 67   http://www.ironhacks.com/preview/alejosaur/web...
# 84   http://www.ironhacks.com/preview/anythinglord/...
# ..                                                 ...
# 261  http://www.ironhacks.com/preview/noah-curran/w...
# ...

# %%
df_color_exp['ssim_exp_scale'] = df_color_exp['ssim_exp'].div(100).round(6)
df_color_exp
# Out:
#              username1          username2  \
# 0    www.ironhacks.com  www.ironhacks.com
# 9    www.ironhacks.com  www.ironhacks.com
# 50   www.ironhacks.com  www.ironhacks.com
# 67   www.ironhacks.com  www.ironhacks.com
# 84   www.ironhacks.com  www.ironhacks.com
# ..                 ...                ...
# 261  www.ironhacks.com  www.ironhacks.com
# 262  www.ironhacks.com  www.ironhacks.com
# 263  www.ironhacks.com  www.ironhacks.com
# 264  www.ironhacks.com  www.ironhacks.com
# 265  www.ironhacks.com  www.ironhacks.com
#
#                                                  link1  \
# 0    http://www.ironhacks.com/preview/BrandonAvilan...
# 9    http://www.ironhacks.com/preview/DaniCastel/we...
# 50   http://www.ironhacks.com/preview/Orloffyeah/we...
# 67   http://www.ironhacks.com/preview/alejosaur/web...
# 84   http://www.ironhacks.com/preview/anythinglord/...
# ..                                                 ...
# 261  http://www.ironhacks.com/preview/noah-curran/w...
# ...

# %%
df_color_exp.to_csv("df_color_exp_unal0.csv")

# %%
# %store -r ind_group0
import pandas as pd
pd.set_option('display.max_rows', 2000)

df_new = ind_group0[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']]

final_unal0 = df_new.append(df_color_exp[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']], ignore_index = True)


final_unal0.to_csv("final_unal0.csv")

final_unal0_functions = final_unal0[final_unal0['comparison_type'] == 'functions']
final_unal0_complete = final_unal0[final_unal0['comparison_type'] == 'complete']
final_unal0_functions_complete = final_unal0_functions.append(final_unal0_complete, ignore_index = True)
final_unal0_functions_complete['ssim_exp_scale'] = final_unal0_functions_complete['ssim_exp'].div(100).round(6)
final_unal0_functions_complete.loc[final_unal0_functions_complete['ssim_exp_scale'] == 1, 'ssim_exp_scale'] = 0.99
final_unal0_functions_complete.loc[final_unal0_functions_complete['ssim_exp_scale'] == 0.0000, 'ssim_exp_scale'] = 0.01
final_unal0_functions_complete.to_csv("final_unal0_functions_complete.csv")
final_unal0_functions_complete
# Out:
#         link1_change     link2_change    ssim_exp  stage comparison_type  \
# 0         biherrerap       biherrerap   50.000000      1       functions
# 1             SionHu           SionHu   11.764706      1       functions
# 2        littlex2015      littlex2015   17.647059      1       functions
# 3             Nigogu           Nigogu   66.666667      1       functions
# 4             AkaGar           AkaGar   54.545455      1       functions
# 5               ko68             ko68   24.390244      1       functions
# 6        whipplem123      whipplem123   80.000000      1       functions
# 7         jmamaril25       jmamaril25   62.500000      1       functions
# 8             Alekzu           Alekzu  100.000000      1       functions
# 9           nbraunec         nbraunec  100.000000      1       functions
# 10       Ilyumzhinov      Ilyumzhinov  100.000000      1       functions
# 11           Camiioo          Camiioo  100.000000      1       functions
# ...

# %%
import networkx as nx
import pandas as pd

df_color_stage1 = df_color[df_color['stage'] == 1]
df_color_stage1 = df_color_stage1[df_color_stage1['link1_change'] != df_color_stage1['link2_change']]
df_color_stage1 = df_color_stage1[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage1,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage1_unal0.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage2 = df_color[df_color['stage'] == 2]
df_color_stage2 = df_color_stage2[df_color_stage2['link1_change'] != df_color_stage2['link2_change']]
df_color_stage2 = df_color_stage2[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage2,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage2_unal0.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage3 = df_color[df_color['stage'] == 3]
df_color_stage3 = df_color_stage3[df_color_stage3['link1_change'] != df_color_stage3['link2_change']]
df_color_stage3 = df_color_stage3[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage3,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage3_unal0.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage4 = df_color[df_color['stage'] == 4]
df_color_stage4 = df_color_stage4[df_color_stage4['stage'] == 4]
df_color_stage4 = df_color_stage4[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage4,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage4_unal0.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage1 = df_color[df_color['stage'] == 1]
df_color_stage1 = df_color_stage1[df_color_stage1['comparison_type'] == "maps"]
df_color_stage1 = df_color_stage1[df_color_stage1['link1_change'] != df_color_stage1['link2_change']]
df_color_stage1 = df_color_stage1[['link1_change', 'link2_change', 'ssim']]


# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage1,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage1_unal0_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage2 = df_color[df_color['stage'] == 2]
df_color_stage2 = df_color_stage2[df_color_stage2['comparison_type'] == "maps"]
df_color_stage2 = df_color_stage2[df_color_stage2['link1_change'] != df_color_stage2['link2_change']]
df_color_stage2 = df_color_stage2[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage2,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage2_unal0_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage3 = df_color[df_color['stage'] == 3]
df_color_stage3 = df_color_stage3[df_color_stage3['comparison_type'] == "maps"]
df_color_stage3 = df_color_stage3[df_color_stage3['link1_change'] != df_color_stage3['link2_change']]
df_color_stage3 = df_color_stage3[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage3,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage3_unal0_map.csv')

# %%
import networkx as nx
import pandas as pd

df_color_stage4 = df_color[df_color['stage'] == 4]
df_color_stage4 = df_color_stage4[df_color_stage4['comparison_type'] == "maps"]
df_color_stage4 = df_color_stage4[df_color_stage4['stage'] == 4]
df_color_stage4 = df_color_stage4[['link1_change', 'link2_change', 'ssim']]

# Create Graph
G = nx.from_pandas_edgelist(
    df_color_stage4,
    source='link2_change',
    target='link1_change',
    edge_attr='ssim'
)

# Build adjacency matrix
adjacency_df = pd.DataFrame(
    nx.adjacency_matrix(G, weight='ssim').todense(),
    index=G.nodes,
    columns=G.nodes
)

adjacency_df.to_csv('stage4_unal0_map.csv')

# %%
final_unal0_functions_complete
# Out:
#         link1_change     link2_change    ssim_exp  stage comparison_type  \
# 0         biherrerap       biherrerap   50.000000      1       functions
# 1             SionHu           SionHu   11.764706      1       functions
# 2        littlex2015      littlex2015   17.647059      1       functions
# 3             Nigogu           Nigogu   66.666667      1       functions
# 4             AkaGar           AkaGar   54.545455      1       functions
# 5               ko68             ko68   24.390244      1       functions
# 6        whipplem123      whipplem123   80.000000      1       functions
# 7         jmamaril25       jmamaril25   62.500000      1       functions
# 8             Alekzu           Alekzu  100.000000      1       functions
# 9           nbraunec         nbraunec  100.000000      1       functions
# 10       Ilyumzhinov      Ilyumzhinov  100.000000      1       functions
# 11           Camiioo          Camiioo  100.000000      1       functions
# ...

# %%
# %store final_unal0_functions_complete
# Out:
# Stored 'final_unal0_functions_complete' (DataFrame)
