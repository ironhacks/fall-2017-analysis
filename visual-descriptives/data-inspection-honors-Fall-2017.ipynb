# %% [markdown]
# ## Descriptive Analysis for Fall 2017 ( Purdue Honors )

# %% [markdown]
# ## Construct panel data for Honors with colors

# %%
import pandas as pd
import seaborn as sns

df_45 = pd.read_csv("../data/Honors-Phase-4-_Honors-Phase-5-raw-results.csv")
df_34 = pd.read_csv("../data/Honors-Phase-3-_Honors-Phase-4–raw-results.csv")
df_23 = pd.read_csv("../data/Honors-Phase-2-_Honors-Phase-3–raw-results.csv")
df_12 = pd.read_csv("../data/Honors-Phase-1-_Honors-Phase-2–raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7281  www.ironhacks.com  www.ironhacks.com
# 7282  www.ironhacks.com  www.ironhacks.com
# 7283  www.ironhacks.com  www.ironhacks.com
# 7284  www.ironhacks.com  www.ironhacks.com
# 7285  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...
# 1     http://www.ironhacks.com/preview/AkaGar/webapp...
# 2     http://www.ironhacks.com/preview/AkaGar/webapp...
# 3     http://www.ironhacks.com/preview/AkaGar/webapp...
# 4     http://www.ironhacks.com/preview/AkaGar/webapp...
# ...                                                 ...
# 7281  http://www.ironhacks.com/preview/zhao744/webap...
# 7282  http://www.ironhacks.com/preview/zhao744/webap...
# 7283  http://www.ironhacks.com/preview/zhao744/webap...
# 7284  http://www.ironhacks.com/preview/zhao744/webap...
# 7285  http://www.ironhacks.com/preview/zhao744/webap...
#
#                                                   link2 comparison_type  ssim  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...            maps  14.0
# 1     http://www.ironhacks.com/preview/GeoffYart/web...            maps  18.7
# 2     http://www.ironhacks.com/preview/bzin22/webapp...            maps  23.4
# 3     http://www.ironhacks.com/preview/hihms/webapp_...            maps  18.8
# 4     http://www.ironhacks.com/preview/jmamaril25/we...            maps  22.1
# ...                                                 ...             ...   ...
# 7281  http://www.ironhacks.com/preview/noah-curran/w...          simple  34.5
# 7282  http://www.ironhacks.com/preview/sanjitsama/we...          simple  60.2
# 7283  http://www.ironhacks.com/preview/shivans/webap...          simple  24.6
# 7284  http://www.ironhacks.com/preview/viswapurdue/w...          simple  25.1
# 7285  http://www.ironhacks.com/preview/whipplem123/w...          simple  88.8
#
#       features2d  stage
# 0           30.5      1
# 1          100.0      1
# 2           35.8      1
# 3           30.9      1
# 4           32.3      1
# ...          ...    ...
# 7281        57.6      4
# 7282        66.1      4
# 7283       100.0      4
# 7284        22.3      4
# 7285        97.0      4
#
# [7286 rows x 8 columns]

# %%
ax = sns.lineplot(data=df_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Construct panel data for Honors with no colors

# %%
df_45 = pd.read_csv("../data/Honors-Phase-4-_Honors-Phase-5–no-color-raw-results.csv")
df_34 = pd.read_csv("../data/Honors-Phase-3-_Honors-Phase-4–no-color-raw-results.csv")
df_23 = pd.read_csv("../data/Honors-Phase-2-_Honors-Phase-3–no-color-raw-results.csv")
df_12 = pd.read_csv("../data/Honors-Phase-1-_Honors-Phase-2–no-color-raw-results.csv")
df_12['stage'] = 1
df_23['stage'] = 2
df_34['stage'] = 3
df_45['stage'] = 4

# %%
df_no_color = pd.concat([df_12, df_23, df_34, df_45], ignore_index=True)
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7281  www.ironhacks.com  www.ironhacks.com
# 7282  www.ironhacks.com  www.ironhacks.com
# 7283  www.ironhacks.com  www.ironhacks.com
# 7284  www.ironhacks.com  www.ironhacks.com
# 7285  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...
# 1     http://www.ironhacks.com/preview/AkaGar/webapp...
# 2     http://www.ironhacks.com/preview/AkaGar/webapp...
# 3     http://www.ironhacks.com/preview/AkaGar/webapp...
# 4     http://www.ironhacks.com/preview/AkaGar/webapp...
# ...                                                 ...
# 7281  http://www.ironhacks.com/preview/zhao744/webap...
# 7282  http://www.ironhacks.com/preview/zhao744/webap...
# 7283  http://www.ironhacks.com/preview/zhao744/webap...
# 7284  http://www.ironhacks.com/preview/zhao744/webap...
# 7285  http://www.ironhacks.com/preview/zhao744/webap...
#
#                                                   link2 comparison_type  ssim  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...            maps  14.6
# 1     http://www.ironhacks.com/preview/GeoffYart/web...            maps  17.7
# 2     http://www.ironhacks.com/preview/bzin22/webapp...            maps  28.6
# 3     http://www.ironhacks.com/preview/hihms/webapp_...            maps  26.8
# 4     http://www.ironhacks.com/preview/jmamaril25/we...            maps  28.6
# ...                                                 ...             ...   ...
# 7281  http://www.ironhacks.com/preview/noah-curran/w...          simple  90.6
# 7282  http://www.ironhacks.com/preview/sanjitsama/we...          simple  89.9
# 7283  http://www.ironhacks.com/preview/shivans/webap...          simple  52.1
# 7284  http://www.ironhacks.com/preview/viswapurdue/w...          simple  49.5
# 7285  http://www.ironhacks.com/preview/whipplem123/w...          simple  93.5
#
#       features2d  stage
# 0           40.1      1
# 1          100.0      1
# 2           50.2      1
# 3           51.0      1
# 4           64.8      1
# ...          ...    ...
# 7281        93.0      4
# 7282        93.0      4
# 7283       100.0      4
# 7284        58.1      4
# 7285        98.0      4
#
# [7286 rows x 8 columns]

# %%
ax = sns.lineplot(data=df_no_color, x='stage', y='ssim', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %% [markdown]
# ## Individual Exploration for Purdue Honors

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7281  www.ironhacks.com  www.ironhacks.com
# 7282  www.ironhacks.com  www.ironhacks.com
# 7283  www.ironhacks.com  www.ironhacks.com
# 7284  www.ironhacks.com  www.ironhacks.com
# 7285  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...
# 1     http://www.ironhacks.com/preview/AkaGar/webapp...
# 2     http://www.ironhacks.com/preview/AkaGar/webapp...
# 3     http://www.ironhacks.com/preview/AkaGar/webapp...
# 4     http://www.ironhacks.com/preview/AkaGar/webapp...
# ...                                                 ...
# 7281  http://www.ironhacks.com/preview/zhao744/webap...
# 7282  http://www.ironhacks.com/preview/zhao744/webap...
# 7283  http://www.ironhacks.com/preview/zhao744/webap...
# 7284  http://www.ironhacks.com/preview/zhao744/webap...
# 7285  http://www.ironhacks.com/preview/zhao744/webap...
#
#                                                   link2 comparison_type  ssim  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...            maps  14.6
# 1     http://www.ironhacks.com/preview/GeoffYart/web...            maps  17.7
# 2     http://www.ironhacks.com/preview/bzin22/webapp...            maps  28.6
# 3     http://www.ironhacks.com/preview/hihms/webapp_...            maps  26.8
# 4     http://www.ironhacks.com/preview/jmamaril25/we...            maps  28.6
# ...                                                 ...             ...   ...
# 7281  http://www.ironhacks.com/preview/noah-curran/w...          simple  90.6
# 7282  http://www.ironhacks.com/preview/sanjitsama/we...          simple  89.9
# 7283  http://www.ironhacks.com/preview/shivans/webap...          simple  52.1
# 7284  http://www.ironhacks.com/preview/viswapurdue/w...          simple  49.5
# 7285  http://www.ironhacks.com/preview/whipplem123/w...          simple  93.5
#
#       features2d  stage link1_change
# 0           40.1      1       AkaGar
# 1          100.0      1       AkaGar
# 2           50.2      1       AkaGar
# 3           51.0      1       AkaGar
# 4           64.8      1       AkaGar
# ...          ...    ...          ...
# 7281        93.0      4      zhao744
# 7282        93.0      4      zhao744
# 7283       100.0      4      zhao744
# 7284        58.1      4      zhao744
# 7285        98.0      4      zhao744
#
# [7286 rows x 9 columns]

# %%
df_color['link1_change'] = df_color['link1'].str.split('/', expand=True)[4]
df_color['link2_change'] = df_color['link2'].str.split('/', expand=True)[4]
df_color
# Out:
#               username1          username2  \
# 0     www.ironhacks.com  www.ironhacks.com
# 1     www.ironhacks.com  www.ironhacks.com
# 2     www.ironhacks.com  www.ironhacks.com
# 3     www.ironhacks.com  www.ironhacks.com
# 4     www.ironhacks.com  www.ironhacks.com
# ...                 ...                ...
# 7281  www.ironhacks.com  www.ironhacks.com
# 7282  www.ironhacks.com  www.ironhacks.com
# 7283  www.ironhacks.com  www.ironhacks.com
# 7284  www.ironhacks.com  www.ironhacks.com
# 7285  www.ironhacks.com  www.ironhacks.com
#
#                                                   link1  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...
# 1     http://www.ironhacks.com/preview/AkaGar/webapp...
# 2     http://www.ironhacks.com/preview/AkaGar/webapp...
# 3     http://www.ironhacks.com/preview/AkaGar/webapp...
# 4     http://www.ironhacks.com/preview/AkaGar/webapp...
# ...                                                 ...
# 7281  http://www.ironhacks.com/preview/zhao744/webap...
# 7282  http://www.ironhacks.com/preview/zhao744/webap...
# 7283  http://www.ironhacks.com/preview/zhao744/webap...
# 7284  http://www.ironhacks.com/preview/zhao744/webap...
# 7285  http://www.ironhacks.com/preview/zhao744/webap...
#
#                                                   link2 comparison_type  ssim  \
# 0     http://www.ironhacks.com/preview/AkaGar/webapp...            maps  14.0
# 1     http://www.ironhacks.com/preview/GeoffYart/web...            maps  18.7
# 2     http://www.ironhacks.com/preview/bzin22/webapp...            maps  23.4
# 3     http://www.ironhacks.com/preview/hihms/webapp_...            maps  18.8
# 4     http://www.ironhacks.com/preview/jmamaril25/we...            maps  22.1
# ...                                                 ...             ...   ...
# 7281  http://www.ironhacks.com/preview/noah-curran/w...          simple  34.5
# 7282  http://www.ironhacks.com/preview/sanjitsama/we...          simple  60.2
# 7283  http://www.ironhacks.com/preview/shivans/webap...          simple  24.6
# 7284  http://www.ironhacks.com/preview/viswapurdue/w...          simple  25.1
# 7285  http://www.ironhacks.com/preview/whipplem123/w...          simple  88.8
#
#       features2d  stage link1_change link2_change
# 0           30.5      1       AkaGar       AkaGar
# 1          100.0      1       AkaGar    GeoffYart
# 2           35.8      1       AkaGar       bzin22
# 3           30.9      1       AkaGar        hihms
# 4           32.3      1       AkaGar   jmamaril25
# ...          ...    ...          ...          ...
# 7281        57.6      4      zhao744  noah-curran
# 7282        66.1      4      zhao744   sanjitsama
# 7283       100.0      4      zhao744      shivans
# 7284        22.3      4      zhao744  viswapurdue
# 7285        97.0      4      zhao744  whipplem123
#
# [7286 rows x 10 columns]

# %%
df_color_exp = df_color[df_color['link1_change'] == df_color['link2_change']]
df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']
# Out:
# <ipython-input-9-24f76cc13a19>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_color_exp['ssim_exp'] = 100 - df_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
df_no_color['link1_change'] = df_no_color['link1'].str.split('/', expand=True)[4]
df_no_color['link2_change'] = df_no_color['link2'].str.split('/', expand=True)[4]
df_no_color_exp = df_no_color[df_no_color['link1_change'] == df_no_color['link2_change']]
df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']
# Out:
# <ipython-input-11-23012f618b3e>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_color_exp['ssim_exp'] = 100 - df_no_color_exp['ssim']

# %%
ax = sns.lineplot(data=df_no_color_exp, x='stage', y='ssim_exp', hue='comparison_type')
ax.legend(loc='center right', bbox_to_anchor=(1.25, 0.5), ncol=1)

# %%
# save variables

df_color_exp.to_csv("df_color_exp_honors0.csv")

# %%
# %store -r ind_group0
pd.set_option('display.max_rows', 2000)

df_new = ind_group3[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']]

final_unal0 = df_new.append(df_color_exp[['link1_change', 'link2_change', 
                       'ssim_exp', 'stage', 'comparison_type']], ignore_index = True)


final_unal0.to_csv("final_unal0.csv")

final_unal0_functions = final_unal0[final_unal0['comparison_type'] == 'functions']
final_unal0_complete = final_unal0[final_unal0['comparison_type'] == 'complete']
final_unal0_functions_complete = final_unal0_functions.append(final_unal0_complete, ignore_index = True)
final_unal0_functions_complete['ssim_exp_scale'] = final_unal0_functions_complete['ssim_exp'].div(100).round(6)
final_unal0_functions_complete.loc[final_unal0_functions_complete['ssim_exp_scale'] == 1, 'ssim_exp_scale'] = 0.9
final_unal0_functions_complete.loc[final_unal0_functions_complete['ssim_exp_scale'] == 0.0000, 'ssim_exp_scale'] = 0.1
final_unal0_functions_complete.to_csv("final_honors0_functions_complete.csv")
final_unal0_functions_complete
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9b45273bb355> in <module>
#       2 pd.set_option('display.max_rows', 2000)
#       3
# ----> 4 df_new = ind_group3[['link1_change', 'link2_change',
#       5                        'ssim_exp', 'stage', 'comparison_type']]
#       6
#
# NameError: name 'ind_group3' is not defined

# %%
# %store -r ind_group0

# %%
ind_group0
# Out:
#                  user1            user2  user1_phase  user2_phase  similarity  \
# 4602        biherrerap       biherrerap            1            2    0.500000
# 8547            SionHu           SionHu            1            2    0.117647
# 10502      littlex2015      littlex2015            1            2    0.176471
# 12209           Nigogu           Nigogu            1            2    0.666667
# 12615           AkaGar           AkaGar            1            2    0.545455
# 13021             ko68             ko68            1            2    0.243902
# 13429      whipplem123      whipplem123            1            2    0.800000
# 14022       jmamaril25       jmamaril25            1            2    0.625000
# 14208           Alekzu           Alekzu            1            2    1.000000
# 15386         nbraunec         nbraunec            1            2    1.000000
# 16864      Ilyumzhinov      Ilyumzhinov            1            2    1.000000
# 18652          Camiioo          Camiioo            1            2    1.000000
# 19322           Gavnic           Gavnic            1            2    1.000000
# 19493         Sariilan         Sariilan            1            2    1.000000
# 19660        nviverosb        nviverosb            1            2    0.592593
# 20170       dieguischa       dieguischa            1            2    0.058824
# 20335         Acreed21         Acreed21            1            2    0.250000
# 22189          ecottle          ecottle            1            2    0.571429
# 22489           Ozai98           Ozai98            1            2    1.000000
# 22961          Daryhez          Daryhez            1            2    0.047619
# 23669       sanjitsama       sanjitsama            1            2    0.058824
# 23816  DiegoAraque1207  DiegoAraque1207            1            2    0.600000
# 23952    SergioLopez40    SergioLopez40            1            2    1.000000
# 24075         yaochoal         yaochoal            1            2    0.150000
# 24348      viswapurdue      viswapurdue            1            2    0.100000
# 24619          matson3          matson3            1            2    0.012821
# 2303        laurenjank       laurenjank            2            3    0.500000
# 3285      JorgeTorresC     JorgeTorresC            2            3    1.000000
# 4751   LukasMMarinovic  LukasMMarinovic            2            3    0.333333
# 7331       daapinzonch      daapinzonch            2            3    0.250000
# 11260           bzin22           bzin22            2            3    0.074074
# 14713        bfprietoc        bfprietoc            2            3    1.000000
# 14903           frnkbs           frnkbs            2            3    0.571429
# 15095          lennwgs          lennwgs            2            3    1.000000
# 16214         vvargasd         vvargasd            2            3    1.000000
# 16395       CampbellC2       CampbellC2            2            3    0.125000
# 16956       Orloffyeah       Orloffyeah            2            3    0.333333
# 20708        GeoffYart        GeoffYart            2            3    0.642857
# 20861         aclipfel         aclipfel            2            3    1.000000
# 21345     anythinglord     anythinglord            2            3    0.120000
# 21951        Jfcastroh        Jfcastroh            2            3    1.000000
# 25166       biherrerap       biherrerap            2            3    1.000000
# 30577      Ilyumzhinov      Ilyumzhinov            2            3    1.000000
# 31014         nbraunec         nbraunec            2            3    0.125000
# 32357          ecottle          ecottle            2            3    0.666667
# 32491           Ozai98           Ozai98            2            3    0.785714
# 32742       dieguischa       dieguischa            2            3    0.023438
# 32848         Acreed21         Acreed21            2            3    1.000000
# 259          mdecloedt        mdecloedt            3            4    0.680000
# 517            zhao744          zhao744            3            4    0.270588
# 1058       daapinzonch      daapinzonch            3            4    0.120000
# 1537           shivans          shivans            3            4    1.000000
# 3523       criscapunal      criscapunal            3            4    0.828571
# 5686      JorgeTorresC     JorgeTorresC            3            4    1.000000
# 9541   LukasMMarinovic  LukasMMarinovic            3            4    1.000000
# 10620      LauraMolina      LauraMolina            3            4    1.000000
# 12297           bzin22           bzin22            3            4    0.293103
# 17302       CampbellC2       CampbellC2            3            4    0.102564
# 21477       Joacampora       Joacampora            3            4    0.800000
# 22682         aclipfel         aclipfel            3            4    1.000000
# 27740           Alekzu           Alekzu            3            4    0.500000
# 27952      whipplem123      whipplem123            3            4    1.000000
# 28365           Nigogu           Nigogu            3            4    0.361702
# 30253         Sariilan         Sariilan            3            4    1.000000
# 30333        nviverosb        nviverosb            3            4    0.666667
# 30783           Gavnic           Gavnic            3            4    0.285714
# 31703      Ilyumzhinov      Ilyumzhinov            3            4    1.000000
# 32186          matson3          matson3            3            4    0.695652
# 32379      viswapurdue      viswapurdue            3            4    0.088235
# 32422         yaochoal         yaochoal            3            4    0.266667
# 32747  DiegoAraque1207  DiegoAraque1207            3            4    0.285714
# 33006          Daryhez          Daryhez            3            4    1.000000
# 27         daapinzonch      daapinzonch            4            5    0.093750
# 33         daapinzonch      daapinzonch            4            5    0.578947
# 798          mdecloedt        mdecloedt            4            5    0.533333
# 1306           zhao744          zhao744            4            5    0.878049
# 1802             hihms            hihms            4            5    0.941176
# 2792           shivans          shivans            4            5    1.000000
# 3792      jmhunter4711     jmhunter4711            4            5    1.000000
# 4270       criscapunal      criscapunal            4            5    0.600000
# 10845      LauraMolina      LauraMolina            4            5    1.000000
# 11480          olimita          olimita            4            5    0.912500
# 20388        snugghash        snugghash            4            5    0.777778
# 21803       Joacampora       Joacampora            4            5    0.793651
# 25420      littlex2015      littlex2015            4            5    1.000000
# 25800           SionHu           SionHu            4            5    1.000000
# 27857           Alekzu           Alekzu            4            5    0.500000
# 28077       jmamaril25       jmamaril25            4            5    0.576577
# 28176      whipplem123      whipplem123            4            5    0.875000
# 28472           AkaGar           AkaGar            4            5    0.730769
# 28572             ko68             ko68            4            5    0.528736
# 28855           Nigogu           Nigogu            4            5    0.918367
# 30501         Sariilan         Sariilan            4            5    1.000000
# 30652        nviverosb        nviverosb            4            5    0.047619
# 30864           Gavnic           Gavnic            4            5    1.000000
# 30944          Camiioo          Camiioo            4            5    1.000000
# 32267          matson3          matson3            4            5    0.450262
# 32528         yaochoal         yaochoal            4            5    0.085106
# 32567      viswapurdue      viswapurdue            4            5    1.000000
# 32815    SergioLopez40    SergioLopez40            4            5    0.500000
# 32876  DiegoAraque1207  DiegoAraque1207            4            5    0.525000
# 33051       sanjitsama       sanjitsama            4            5    1.000000
# 33073          Daryhez          Daryhez            4            5    1.000000
#
#        stage  exploration comparison_type    ssim_exp     link1_change  \
# 4602       1     0.500000       functions   50.000000       biherrerap
# 8547       1     0.882353       functions   11.764706           SionHu
# 10502      1     0.823529       functions   17.647059      littlex2015
# 12209      1     0.333333       functions   66.666667           Nigogu
# 12615      1     0.454545       functions   54.545455           AkaGar
# 13021      1     0.756098       functions   24.390244             ko68
# 13429      1     0.200000       functions   80.000000      whipplem123
# 14022      1     0.375000       functions   62.500000       jmamaril25
# 14208      1     0.000000       functions  100.000000           Alekzu
# 15386      1     0.000000       functions  100.000000         nbraunec
# 16864      1     0.000000       functions  100.000000      Ilyumzhinov
# 18652      1     0.000000       functions  100.000000          Camiioo
# 19322      1     0.000000       functions  100.000000           Gavnic
# 19493      1     0.000000       functions  100.000000         Sariilan
# 19660      1     0.407407       functions   59.259259        nviverosb
# 20170      1     0.941176       functions    5.882353       dieguischa
# 20335      1     0.750000       functions   25.000000         Acreed21
# 22189      1     0.428571       functions   57.142857          ecottle
# 22489      1     0.000000       functions  100.000000           Ozai98
# 22961      1     0.952381       functions    4.761905          Daryhez
# 23669      1     0.941176       functions    5.882353       sanjitsama
# 23816      1     0.400000       functions   60.000000  DiegoAraque1207
# 23952      1     0.000000       functions  100.000000    SergioLopez40
# 24075      1     0.850000       functions   15.000000         yaochoal
# 24348      1     0.900000       functions   10.000000      viswapurdue
# 24619      1     0.987179       functions    1.282051          matson3
# 2303       2     0.500000       functions   50.000000       laurenjank
# 3285       2     0.000000       functions  100.000000     JorgeTorresC
# 4751       2     0.666667       functions   33.333333  LukasMMarinovic
# 7331       2     0.750000       functions   25.000000      daapinzonch
# 11260      2     0.925926       functions    7.407407           bzin22
# 14713      2     0.000000       functions  100.000000        bfprietoc
# 14903      2     0.428571       functions   57.142857           frnkbs
# 15095      2     0.000000       functions  100.000000          lennwgs
# 16214      2     0.000000       functions  100.000000         vvargasd
# 16395      2     0.875000       functions   12.500000       CampbellC2
# 16956      2     0.666667       functions   33.333333       Orloffyeah
# 20708      2     0.357143       functions   64.285714        GeoffYart
# 20861      2     0.000000       functions  100.000000         aclipfel
# 21345      2     0.880000       functions   12.000000     anythinglord
# 21951      2     0.000000       functions  100.000000        Jfcastroh
# 25166      2     0.000000       functions  100.000000       biherrerap
# 30577      2     0.000000       functions  100.000000      Ilyumzhinov
# 31014      2     0.875000       functions   12.500000         nbraunec
# 32357      2     0.333333       functions   66.666667          ecottle
# 32491      2     0.214286       functions   78.571429           Ozai98
# 32742      2     0.976562       functions    2.343750       dieguischa
# 32848      2     0.000000       functions  100.000000         Acreed21
# 259        3     0.320000       functions   68.000000        mdecloedt
# 517        3     0.729412       functions   27.058824          zhao744
# 1058       3     0.880000       functions   12.000000      daapinzonch
# 1537       3     0.000000       functions  100.000000          shivans
# 3523       3     0.171429       functions   82.857143      criscapunal
# 5686       3     0.000000       functions  100.000000     JorgeTorresC
# 9541       3     0.000000       functions  100.000000  LukasMMarinovic
# 10620      3     0.000000       functions  100.000000      LauraMolina
# 12297      3     0.706897       functions   29.310345           bzin22
# 17302      3     0.897436       functions   10.256410       CampbellC2
# 21477      3     0.200000       functions   80.000000       Joacampora
# 22682      3     0.000000       functions  100.000000         aclipfel
# 27740      3     0.500000       functions   50.000000           Alekzu
# 27952      3     0.000000       functions  100.000000      whipplem123
# 28365      3     0.638298       functions   36.170213           Nigogu
# 30253      3     0.000000       functions  100.000000         Sariilan
# 30333      3     0.333333       functions   66.666667        nviverosb
# 30783      3     0.714286       functions   28.571429           Gavnic
# 31703      3     0.000000       functions  100.000000      Ilyumzhinov
# 32186      3     0.304348       functions   69.565217          matson3
# 32379      3     0.911765       functions    8.823529      viswapurdue
# 32422      3     0.733333       functions   26.666667         yaochoal
# 32747      3     0.714286       functions   28.571429  DiegoAraque1207
# 33006      3     0.000000       functions  100.000000          Daryhez
# 27         4     0.906250       functions    9.375000      daapinzonch
# 33         4     0.421053       functions   57.894737      daapinzonch
# 798        4     0.466667       functions   53.333333        mdecloedt
# 1306       4     0.121951       functions   87.804878          zhao744
# 1802       4     0.058824       functions   94.117647            hihms
# 2792       4     0.000000       functions  100.000000          shivans
# 3792       4     0.000000       functions  100.000000     jmhunter4711
# 4270       4     0.400000       functions   60.000000      criscapunal
# 10845      4     0.000000       functions  100.000000      LauraMolina
# 11480      4     0.087500       functions   91.250000          olimita
# 20388      4     0.222222       functions   77.777778        snugghash
# 21803      4     0.206349       functions   79.365079       Joacampora
# 25420      4     0.000000       functions  100.000000      littlex2015
# 25800      4     0.000000       functions  100.000000           SionHu
# 27857      4     0.500000       functions   50.000000           Alekzu
# 28077      4     0.423423       functions   57.657658       jmamaril25
# 28176      4     0.125000       functions   87.500000      whipplem123
# 28472      4     0.269231       functions   73.076923           AkaGar
# 28572      4     0.471264       functions   52.873563             ko68
# 28855      4     0.081633       functions   91.836735           Nigogu
# 30501      4     0.000000       functions  100.000000         Sariilan
# 30652      4     0.952381       functions    4.761905        nviverosb
# 30864      4     0.000000       functions  100.000000           Gavnic
# 30944      4     0.000000       functions  100.000000          Camiioo
# 32267      4     0.549738       functions   45.026178          matson3
# 32528      4     0.914894       functions    8.510638         yaochoal
# 32567      4     0.000000       functions  100.000000      viswapurdue
# 32815      4     0.500000       functions   50.000000    SergioLopez40
# 32876      4     0.475000       functions   52.500000  DiegoAraque1207
# 33051      4     0.000000       functions  100.000000       sanjitsama
# 33073      4     0.000000       functions  100.000000          Daryhez
#
#           link2_change
# 4602        biherrerap
# 8547            SionHu
# 10502      littlex2015
# 12209           Nigogu
# 12615           AkaGar
# 13021             ko68
# 13429      whipplem123
# 14022       jmamaril25
# 14208           Alekzu
# 15386         nbraunec
# 16864      Ilyumzhinov
# 18652          Camiioo
# 19322           Gavnic
# 19493         Sariilan
# 19660        nviverosb
# 20170       dieguischa
# 20335         Acreed21
# 22189          ecottle
# 22489           Ozai98
# 22961          Daryhez
# 23669       sanjitsama
# 23816  DiegoAraque1207
# 23952    SergioLopez40
# 24075         yaochoal
# 24348      viswapurdue
# 24619          matson3
# 2303        laurenjank
# 3285      JorgeTorresC
# 4751   LukasMMarinovic
# 7331       daapinzonch
# 11260           bzin22
# 14713        bfprietoc
# 14903           frnkbs
# 15095          lennwgs
# 16214         vvargasd
# 16395       CampbellC2
# 16956       Orloffyeah
# 20708        GeoffYart
# 20861         aclipfel
# 21345     anythinglord
# 21951        Jfcastroh
# 25166       biherrerap
# 30577      Ilyumzhinov
# 31014         nbraunec
# 32357          ecottle
# 32491           Ozai98
# 32742       dieguischa
# 32848         Acreed21
# 259          mdecloedt
# 517            zhao744
# 1058       daapinzonch
# 1537           shivans
# 3523       criscapunal
# 5686      JorgeTorresC
# 9541   LukasMMarinovic
# 10620      LauraMolina
# 12297           bzin22
# 17302       CampbellC2
# 21477       Joacampora
# 22682         aclipfel
# 27740           Alekzu
# 27952      whipplem123
# 28365           Nigogu
# 30253         Sariilan
# 30333        nviverosb
# 30783           Gavnic
# 31703      Ilyumzhinov
# 32186          matson3
# 32379      viswapurdue
# 32422         yaochoal
# 32747  DiegoAraque1207
# 33006          Daryhez
# 27         daapinzonch
# 33         daapinzonch
# 798          mdecloedt
# 1306           zhao744
# 1802             hihms
# 2792           shivans
# 3792      jmhunter4711
# 4270       criscapunal
# 10845      LauraMolina
# 11480          olimita
# 20388        snugghash
# 21803       Joacampora
# 25420      littlex2015
# 25800           SionHu
# 27857           Alekzu
# 28077       jmamaril25
# 28176      whipplem123
# 28472           AkaGar
# 28572             ko68
# 28855           Nigogu
# 30501         Sariilan
# 30652        nviverosb
# 30864           Gavnic
# 30944          Camiioo
# 32267          matson3
# 32528         yaochoal
# 32567      viswapurdue
# 32815    SergioLopez40
# 32876  DiegoAraque1207
# 33051       sanjitsama
# 33073          Daryhez
